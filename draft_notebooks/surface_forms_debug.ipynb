# %%
import json

with open('../skillNer/data/skill_db_relax_20.json', 'r+') as f:
    skills_db = json.load(f)

# %%
a =[(key,skills_db[key]) for key in skills_db if skills_db[key]['skill_len']==2 and len(skills_db[key]['low_surface_forms'])>2 ]
len(a)
# Out:
# 3715

# %%
a
# Out:
# [('KS120P86XDXZJT3B7KVJ',
#   {'skill_name': '(American Society For Quality) ASQ Certified',
#    'skill_type': 'Certification',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'asq certify'},
#    'low_surface_forms': ['asq certifi', 'certifi asq', 'asq'],
#    'match_on_tokens': False}),
#  ('KS126Y166NXP5X1SLV6V',
#   {'skill_name': '.NET Reflector',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'net reflector'},
#    'low_surface_forms': ['net reflector', 'reflector net', 'reflector'],
#    'match_on_tokens': False}),
#  ('KS1200Y714QV48TFJ75H',
#   {'skill_name': '2D Animation',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': '2d animation'},
#    'low_surface_forms': ['2d anim', 'anim 2d', '2d'],
#    'match_on_tokens': False}),
#  ('KS1201N5W7VSFRRRSTRK',
#   {'skill_name': '3Dvia Composer',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': '3dvia composer'},
#    'low_surface_forms': ['3dvia compos', 'compos 3dvia', '3dvia'],
#    'match_on_tokens': False}),
#  ('KS19FJP0CNPJXPM97V7O',
#   {'skill_name': '960.gs',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': '960 gs'},
#    'low_surface_forms': ['960 gs', 'gs 960', 'gs'],
#    'match_on_tokens': False}),
#  ('KS1202C6JFLKXGK47XW3',
#   {'skill_name': 'A431 Cells (Cell Lines)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'a431 cell'},
#    'low_surface_forms': ['a431 cell', 'cell a431', 'a431'],
#    'match_on_tokens': False}),
#  ('ES9F1D46BD135CEEA989',
#   {'skill_name': 'ABA Intervention',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aba intervention'},
#    'low_surface_forms': ['aba intervent', 'intervent aba', 'aba'],
#    'match_on_tokens': False}),
#  ('KS1202P6J5TD8XJJDTX6',
#   {'skill_name': 'ABC FlowCharter',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abc flowcharter'},
#    'low_surface_forms': ['abc flowchart', 'flowchart abc', 'flowchart'],
#    'match_on_tokens': False}),
#  ('KS7G21Y701HRNDL7K2BB',
#   {'skill_name': 'ABL Radiometers',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abl radiometer'},
#    'low_surface_forms': ['abl radiomet', 'radiomet abl', 'radiomet'],
#    'match_on_tokens': False}),
#  ('KS7G22P6T9B338MBV6XT',
#   {'skill_name': 'ABR Routers',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abr router'},
#    'low_surface_forms': ['abr router', 'router abr', 'abr'],
#    'match_on_tokens': False}),
#  ('KS1203S69HZNSXKGVYHM',
#   {'skill_name': 'ACCOL Workbench',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'accol workbench'},
#    'low_surface_forms': ['accol workbench', 'workbench accol', 'accol'],
#    'match_on_tokens': False}),
#  ('KS120456MSP4Z4754XJB',
#   {'skill_name': 'ACCP Certified',
#    'skill_type': 'Certification',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'accp certify'},
#    'low_surface_forms': ['accp certifi', 'certifi accp', 'accp'],
#    'match_on_tokens': False}),
#  ('KS120686DMTSPHYZNFJG',
#   {'skill_name': 'ADATE Systems',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adate system'},
#    'low_surface_forms': ['adat system', 'system adat', 'adat'],
#    'match_on_tokens': False}),
#  ('KS1206J62C99L94MZ28Q',
#   {'skill_name': 'ADHM Construction',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adhm construction'},
#    'low_surface_forms': ['adhm construct', 'construct adhm', 'adhm'],
#    'match_on_tokens': False}),
#  ('KS1206T6DR6QD8JMTQY4',
#   {'skill_name': 'ADO.NET (Programming Language)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ado net'},
#    'low_surface_forms': ['ado net', 'net ado', 'ado'],
#    'match_on_tokens': False}),
#  ('KS1207T744VB0726415M',
#   {'skill_name': 'ADODC Class',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adodc class'},
#    'low_surface_forms': ['adodc class', 'class adodc', 'adodc'],
#    'match_on_tokens': False}),
#  ('KS1207X64LWTF77RX15S',
#   {'skill_name': 'ADOMD.NET',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adomd net'},
#    'low_surface_forms': ['adomd net', 'net adomd', 'adomd'],
#    'match_on_tokens': False}),
#  ('ES1C15D7D4543868E56E',
#   {'skill_name': 'ADP SmartCompliance',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adp smartcompliance'},
#    'low_surface_forms': ['adp smartcompli', 'smartcompli adp', 'smartcompli'],
#    'match_on_tokens': False}),
#  ('ES7DCEC0A13385EEAD75',
#   {'skill_name': 'ADP TotalSource',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adp totalsource'},
#    'low_surface_forms': ['adp totalsourc', 'totalsourc adp', 'totalsourc'],
#    'match_on_tokens': False}),
#  ('ESEC094F51B4AA2A7452',
#   {'skill_name': 'ADP Vantage',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adp vantage'},
#    'low_surface_forms': ['adp vantag', 'vantag adp', 'vantag'],
#    'match_on_tokens': False}),
#  ('KS120F573NR7HPRZCZWM',
#   {'skill_name': 'ALT Linux',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alt linux'},
#    'low_surface_forms': ['alt linux', 'linux alt', 'alt'],
#    'match_on_tokens': False}),
#  ('KS120QP646KKKWKL28NF',
#   {'skill_name': 'AMD CrossFireX',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amd crossfirex'},
#    'low_surface_forms': ['amd crossfirex', 'crossfirex amd', 'crossfirex'],
#    'match_on_tokens': False}),
#  ('ES1A3DE851CDC61EAEE4',
#   {'skill_name': 'AMX Programming',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amx programming'},
#    'low_surface_forms': ['amx program', 'program amx', 'amx'],
#    'match_on_tokens': False}),
#  ('KS120GX6ZR3PQRWT4HZ5',
#   {'skill_name': 'ANCC Certified',
#    'skill_type': 'Certification',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ancc certify'},
#    'low_surface_forms': ['ancc certifi', 'certifi ancc', 'ancc'],
#    'match_on_tokens': False}),
#  ('ESB8C30E646A8D126D9D',
#   {'skill_name': 'ANSYS IcePak (Simulation Software)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ansys icepak'},
#    'low_surface_forms': ['ansi icepak', 'icepak ansi', 'icepak'],
#    'match_on_tokens': False}),
#  ('KS120JJ69JS4Y7D3GT76',
#   {'skill_name': 'AP Stylebook',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ap stylebook'},
#    'low_surface_forms': ['ap stylebook', 'stylebook ap', 'stylebook'],
#    'match_on_tokens': False}),
#  ('KS120N160BXHQ7KC0CCN',
#   {'skill_name': 'ARINC Standards',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'arinc standard'},
#    'low_surface_forms': ['arinc standard', 'standard arinc', 'arinc'],
#    'match_on_tokens': False}),
#  ('KS120N35W6P190K9B7YT',
#   {'skill_name': 'ARM Architecture',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'arm architecture'},
#    'low_surface_forms': ['arm architectur', 'architectur arm', 'arm'],
#    'match_on_tokens': False}),
#  ('KS120N360W96BTJHB9J6',
#   {'skill_name': 'ARM Microarchitectures',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'arm microarchitecture'},
#    'low_surface_forms': ['arm microarchitectur',
#     'microarchitectur arm',
#     'microarchitectur'],
#    'match_on_tokens': False}),
#  ('KS120N374GTJHVC7C3HB',
#   {'skill_name': 'ARM7 Architecture',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'arm7 architecture'},
#    'low_surface_forms': ['arm7 architectur', 'architectur arm7', 'arm7'],
#    'match_on_tokens': False}),
#  ('KS120N46X6LFXVZX4PT8',
#   {'skill_name': 'ARM9 Architecture',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'arm9 architecture'},
#    'low_surface_forms': ['arm9 architectur', 'architectur arm9', 'arm9'],
#    'match_on_tokens': False}),
#  ('ES3B21EEEDAE30A6D435',
#   {'skill_name': 'ASC 606 (Revenue Recognition)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'asc 606'},
#    'low_surface_forms': ['asc 606', '606 asc', '606'],
#    'match_on_tokens': False}),
#  ('KS123TQ761C17LV3KCZL',
#   {'skill_name': 'ASC 740 (Accounting For Income Taxes)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'asc 740'},
#    'low_surface_forms': ['asc 740', '740 asc', '740'],
#    'match_on_tokens': False}),
#  ('ES9DD1674BB7DBE36AD6',
#   {'skill_name': 'ASC 842 (Lease Accounting Standard)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'asc 842'},
#    'low_surface_forms': ['asc 842', '842 asc', '842'],
#    'match_on_tokens': False}),
#  ('KS120026VL50QFWT2281',
#   {'skill_name': 'ASP.NET',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'asp net'},
#    'low_surface_forms': ['asp net', 'net asp', 'asp'],
#    'match_on_tokens': False}),
#  ('KS120PZ67ZB2XW1DY35G',
#   {'skill_name': 'ASSR Certified',
#    'skill_type': 'Certification',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'assr certify'},
#    'low_surface_forms': ['assr certifi', 'certifi assr', 'assr'],
#    'match_on_tokens': False}),
#  ('KS120QQ64GQM67DYJ0N6',
#   {'skill_name': 'ATL Server',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'atl server'},
#    'low_surface_forms': ['atl server', 'server atl', 'atl'],
#    'match_on_tokens': False}),
#  ('KS120QT623D8TCX7251D',
#   {'skill_name': 'ATM Controllers',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'atm controller'},
#    'low_surface_forms': ['atm control', 'control atm', 'atm'],
#    'match_on_tokens': False}),
#  ('KS120TY6VMKTW69X09NF',
#   {'skill_name': 'AVL Tree',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'avl tree'},
#    'low_surface_forms': ['avl tree', 'tree avl', 'avl'],
#    'match_on_tokens': False}),
#  ('ES9D43585B5783E22072',
#   {'skill_name': 'AWS AppSync',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws appsync'},
#    'low_surface_forms': ['aw appsync', 'appsync aw', 'appsync'],
#    'match_on_tokens': False}),
#  ('ESB3F99C3446845F41F6',
#   {'skill_name': 'AWS CloudFormation',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws cloudformation'},
#    'low_surface_forms': ['aw cloudform', 'cloudform aw', 'cloudform'],
#    'match_on_tokens': False}),
#  ('ES323762B1E71B5B0976',
#   {'skill_name': 'AWS CloudHSM',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws cloudhsm'},
#    'low_surface_forms': ['aw cloudhsm', 'cloudhsm aw', 'cloudhsm'],
#    'match_on_tokens': False}),
#  ('ES6C84FF059A9F04F65E',
#   {'skill_name': 'AWS CloudTrail',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws cloudtrail'},
#    'low_surface_forms': ['aw cloudtrail', 'cloudtrail aw', 'cloudtrail'],
#    'match_on_tokens': False}),
#  ('ESD020B052E485B421A3',
#   {'skill_name': 'AWS CodeBuild',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws codebuild'},
#    'low_surface_forms': ['aw codebuild', 'codebuild aw', 'codebuild'],
#    'match_on_tokens': False}),
#  ('ES2119F2B7CEE19988ED',
#   {'skill_name': 'AWS CodeCommit',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws codecommit'},
#    'low_surface_forms': ['aw codecommit', 'codecommit aw', 'codecommit'],
#    'match_on_tokens': False}),
#  ('ES192CD34322D5FBBF42',
#   {'skill_name': 'AWS CodeDeploy',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws codedeploy'},
#    'low_surface_forms': ['aw codedeploy', 'codedeploy aw', 'codedeploy'],
#    'match_on_tokens': False}),
#  ('ES81E615088FE9EDB504',
#   {'skill_name': 'AWS CodePipeline',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws codepipeline'},
#    'low_surface_forms': ['aw codepipelin', 'codepipelin aw', 'codepipelin'],
#    'match_on_tokens': False}),
#  ('ES363E5FFEDC2CBB5A4D',
#   {'skill_name': 'AWS Inferentia',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws inferentia'},
#    'low_surface_forms': ['aw inferentia', 'inferentia aw', 'inferentia'],
#    'match_on_tokens': False}),
#  ('ES4512E57CF178E77F7B',
#   {'skill_name': 'AWS Kinesis',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws kinesis'},
#    'low_surface_forms': ['aw kinesi', 'kinesi aw', 'kinesi'],
#    'match_on_tokens': False}),
#  ('ES2133DA6434CF028833',
#   {'skill_name': 'AWS SageMaker',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aws sagemaker'},
#    'low_surface_forms': ['aw sagemak', 'sagemak aw', 'sagemak'],
#    'match_on_tokens': False}),
#  ('ES52C92B8516F3CFD53F',
#   {'skill_name': 'Ab Initio (Software)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ab initio'},
#    'low_surface_forms': ['ab initio', 'initio ab', 'initio'],
#    'match_on_tokens': False}),
#  ('KS1202P6CWB7Y5KCB78N',
#   {'skill_name': 'Abc Analysis',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abc analysis'},
#    'low_surface_forms': ['abc analysi', 'analysi abc', 'abc'],
#    'match_on_tokens': False}),
#  ('KS1202R6Q0F9WFQR874Z',
#   {'skill_name': 'Abdominal Surgery',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abdominal surgery'},
#    'low_surface_forms': ['abdomin surgeri', 'surgeri abdomin', 'abdomin'],
#    'match_on_tokens': False}),
#  ('KS1202Y6YB65J9CFR5YC',
#   {'skill_name': 'Ableton Live',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ableton live'},
#    'low_surface_forms': ['ableton live', 'live ableton', 'ableton'],
#    'match_on_tokens': False}),
#  ('KS7G5166Y7RLLM3ZFW86',
#   {'skill_name': 'Aboriginal Law',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aboriginal law'},
#    'low_surface_forms': ['aborigin law', 'law aborigin', 'aborigin'],
#    'match_on_tokens': False}),
#  ('KS120336GQFKVT54QV78',
#   {'skill_name': 'Abrasive Saw',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abrasive saw'},
#    'low_surface_forms': ['abras saw', 'saw abras', 'abras'],
#    'match_on_tokens': False}),
#  ('KS125QD6THVTXDY344MP',
#   {'skill_name': 'Absolute Manage',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'absolute manage'},
#    'low_surface_forms': ['absolut manag', 'manag absolut', 'absolut'],
#    'match_on_tokens': False}),
#  ('KS1228L6JG2Z7Y9388W1',
#   {'skill_name': 'Abstract Management',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'abstract management'},
#    'low_surface_forms': ['abstract manag', 'manag abstract', 'abstract'],
#    'match_on_tokens': False}),
#  ('KS1203J6M8VRNS2CHDR6',
#   {'skill_name': 'Accent Reduction',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'accent reduction'},
#    'low_surface_forms': ['accent reduct', 'reduct accent', 'accent'],
#    'match_on_tokens': False}),
#  ('KS1203K6FQ749NJNRBBX',
#   {'skill_name': 'Acceptance Testing',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'acceptance testing'},
#    'low_surface_forms': ['accept test', 'test accept', 'accept'],
#    'match_on_tokens': False}),
#  ('KS1203R63NCPN34ZBVST',
#   {'skill_name': 'Access Stratum',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'access stratum'},
#    'low_surface_forms': ['access stratum', 'stratum access', 'stratum'],
#    'match_on_tokens': False}),
#  ('KS2Z5CPHEKWSRR4CGU3K',
#   {'skill_name': 'Accord.net',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'accord net'},
#    'low_surface_forms': ['accord net', 'net accord', 'accord'],
#    'match_on_tokens': False}),
#  ('KS120496WQCJDPL7THP5',
#   {'skill_name': 'Accrual Accounting',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'accrual accounting'},
#    'low_surface_forms': ['accrual account', 'account accrual', 'accrual'],
#    'match_on_tokens': False}),
#  ('KS1204B65GL24XD81P45',
#   {'skill_name': 'Accrued Liabilities',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'accrue liability'},
#    'low_surface_forms': ['accru liabil', 'liabil accru', 'accru'],
#    'match_on_tokens': False}),
#  ('KS1204Q6L6ZWF5QJ4BMY',
#   {'skill_name': 'Acid Hydrolysis',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'acid hydrolysis'},
#    'low_surface_forms': ['acid hydrolysi', 'hydrolysi acid', 'hydrolysi'],
#    'match_on_tokens': False}),
#  ('KS120556WGBNC5V3VQXQ',
#   {'skill_name': 'Acquisition Processes',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'acquisition process'},
#    'low_surface_forms': ['acquisit process', 'process acquisit', 'acquisit'],
#    'match_on_tokens': False}),
#  ('ESCD0066FBF8BD7D60F4',
#   {'skill_name': 'Acrylic Paint',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'acrylic paint'},
#    'low_surface_forms': ['acryl paint', 'paint acryl', 'acryl'],
#    'match_on_tokens': False}),
#  ('KS440NL759FHR7WC06YM',
#   {'skill_name': 'Actel SmartFusion',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'actel smartfusion'},
#    'low_surface_forms': ['actel smartfus', 'smartfus actel', 'smartfus'],
#    'match_on_tokens': False}),
#  ('KS441RQ74BZXRP355M4Z',
#   {'skill_name': 'Actian Vector',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'actian vector'},
#    'low_surface_forms': ['actian vector', 'vector actian', 'actian'],
#    'match_on_tokens': False}),
#  ('KSCKLO0C6OB2WV83H6XO',
#   {'skill_name': 'Active Hdl',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'active hdl'},
#    'low_surface_forms': ['activ hdl', 'hdl activ', 'hdl'],
#    'match_on_tokens': False}),
#  ('KS1205M65BKF2V200RX0',
#   {'skill_name': 'ActiveState Komodo (Unix Text Editors)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'activestate komodo'},
#    'low_surface_forms': ['activest komodo', 'komodo activest', 'komodo'],
#    'match_on_tokens': False}),
#  ('KS1205Q77Q3SVS3TX87M',
#   {'skill_name': 'ActiveX Document',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'activex document'},
#    'low_surface_forms': ['activex document', 'document activex', 'activex'],
#    'match_on_tokens': False}),
#  ('KS9IBUH88YSMGKPYVQXD',
#   {'skill_name': 'Activity Manager',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'activity manager'},
#    'low_surface_forms': ['activ manag', 'manag activ', 'activ'],
#    'match_on_tokens': False}),
#  ('KSX2IBZ23N66EQ3LAJIL',
#   {'skill_name': 'Actor Model',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'actor model'},
#    'low_surface_forms': ['actor model', 'model actor', 'actor'],
#    'match_on_tokens': False}),
#  ('KS1205V67QP3VYT0HKW7',
#   {'skill_name': 'Actuarial Science',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'actuarial science'},
#    'low_surface_forms': ['actuari scienc', 'scienc actuari', 'actuari'],
#    'match_on_tokens': False}),
#  ('KS1RQLEJQ4336UADC164',
#   {'skill_name': 'Ada Compliance',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ada compliance'},
#    'low_surface_forms': ['ada complianc', 'complianc ada', 'ada'],
#    'match_on_tokens': False}),
#  ('KS1206C5WMYP96Y8LPBC',
#   {'skill_name': 'Addiction Medicine',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'addiction medicine'},
#    'low_surface_forms': ['addict medicin', 'medicin addict', 'addict'],
#    'match_on_tokens': False}),
#  ('KS1206C61PVXSBBFM58L',
#   {'skill_name': 'Additive Manufacturing',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'additive manufacturing'},
#    'low_surface_forms': ['addit manufactur', 'manufactur addit', 'addit'],
#    'match_on_tokens': False}),
#  ('KS1206J5XYR90LBTKZ06',
#   {'skill_name': 'Adhesive Bonding',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adhesive bonding'},
#    'low_surface_forms': ['adhes bond', 'bond adhes', 'adhes'],
#    'match_on_tokens': False}),
#  ('KS0U36DG9Y1PX3SEGGKO',
#   {'skill_name': 'Adhoc Queries',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adhoc query'},
#    'low_surface_forms': ['adhoc queri', 'queri adhoc', 'adhoc'],
#    'match_on_tokens': False}),
#  ('KS1206J66Y7XNYCYGDBW',
#   {'skill_name': 'Adipose Tissue',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adipose tissue'},
#    'low_surface_forms': ['adipos tissu', 'tissu adipos', 'adipos'],
#    'match_on_tokens': False}),
#  ('KS1206J756QN3DXVB6V2',
#   {'skill_name': 'Adjacency Matrix',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adjacency matrix'},
#    'low_surface_forms': ['adjac matrix', 'matrix adjac', 'adjac'],
#    'match_on_tokens': False}),
#  ('KS1206K65FLW37R4W4Z5',
#   {'skill_name': 'Adjudication Process',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adjudication process'},
#    'low_surface_forms': ['adjud process', 'process adjud', 'adjud'],
#    'match_on_tokens': False}),
#  ('KS1206L705PY5CVF4SWG',
#   {'skill_name': 'Adlib Software',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adlib software'},
#    'low_surface_forms': ['adlib softwar', 'softwar adlib', 'adlib'],
#    'match_on_tokens': False}),
#  ('KS1206P65D66ZCYT86NP',
#   {'skill_name': 'Admin Tools',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'admin tool'},
#    'low_surface_forms': ['admin tool', 'tool admin', 'admin'],
#    'match_on_tokens': False}),
#  ('KS440JZ70B5XLQQCXKGR',
#   {'skill_name': 'Admiralty Law',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'admiralty law'},
#    'low_surface_forms': ['admiralti law', 'law admiralti', 'admiralti'],
#    'match_on_tokens': False}),
#  ('KSEJWTKAA1P00B63W2BR',
#   {'skill_name': 'Admissions Operation',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'admission operation'},
#    'low_surface_forms': ['admiss oper', 'oper admiss', 'admiss'],
#    'match_on_tokens': False}),
#  ('KS120586JML0BZT76FZM',
#   {'skill_name': 'Adobe Acrobat',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe acrobat'},
#    'low_surface_forms': ['adob acrobat', 'acrobat adob', 'acrobat'],
#    'match_on_tokens': False}),
#  ('KS1206X605V9JHHBP3FT',
#   {'skill_name': 'Adobe Authorware',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe authorware'},
#    'low_surface_forms': ['adob authorwar', 'authorwar adob', 'authorwar'],
#    'match_on_tokens': False}),
#  ('KS1206Y7570V96J5Y39Y',
#   {'skill_name': 'Adobe Captivate',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe captivate'},
#    'low_surface_forms': ['adob captiv', 'captiv adob', 'captiv'],
#    'match_on_tokens': False}),
#  ('KS120716BRPY331DHGNF',
#   {'skill_name': 'Adobe CreatePDF',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe createpdf'},
#    'low_surface_forms': ['adob createpdf', 'createpdf adob', 'createpdf'],
#    'match_on_tokens': False}),
#  ('KS1207376KPZQ82LQS5H',
#   {'skill_name': 'Adobe Encore',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe encore'},
#    'low_surface_forms': ['adob encor', 'encor adob', 'encor'],
#    'match_on_tokens': False}),
#  ('KS120756HGMH7JGWF85S',
#   {'skill_name': 'Adobe Fireworks',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe firework'},
#    'low_surface_forms': ['adob firework', 'firework adob', 'firework'],
#    'match_on_tokens': False}),
#  ('KS1207B6K2PXN0LKN1S3',
#   {'skill_name': 'Adobe FrameMaker',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe framemaker'},
#    'low_surface_forms': ['adob framemak', 'framemak adob', 'framemak'],
#    'match_on_tokens': False}),
#  ('KS1207B70WD9LT9V1R0V',
#   {'skill_name': 'Adobe FreeHand',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe freehand'},
#    'low_surface_forms': ['adob freehand', 'freehand adob', 'freehand'],
#    'match_on_tokens': False}),
#  ('KS1207B77HYDH8RHX4DZ',
#   {'skill_name': 'Adobe GoLive',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe golive'},
#    'low_surface_forms': ['adob goliv', 'goliv adob', 'goliv'],
#    'match_on_tokens': False}),
#  ('KS1207C76TX2QJ60PKQS',
#   {'skill_name': 'Adobe ImageReady',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe imageready'},
#    'low_surface_forms': ['adob imagereadi', 'imagereadi adob', 'imagereadi'],
#    'match_on_tokens': False}),
#  ('KS1207D6BL4H9JW6ZSJ3',
#   {'skill_name': 'Adobe InCopy',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe incopy'},
#    'low_surface_forms': ['adob incopi', 'incopi adob', 'incopi'],
#    'match_on_tokens': False}),
#  ('KS1207D5ZZHHQZ7JBD7G',
#   {'skill_name': 'Adobe InDesign',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe indesign'},
#    'low_surface_forms': ['adob indesign', 'indesign adob', 'indesign'],
#    'match_on_tokens': False}),
#  ('KS1207D6RSLQV9L6HCWD',
#   {'skill_name': 'Adobe JRun',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe jrun'},
#    'low_surface_forms': ['adob jrun', 'jrun adob', 'jrun'],
#    'match_on_tokens': False}),
#  ('KS125NV6CNQGL0SJ78Q2',
#   {'skill_name': 'Adobe Kuler (Software)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe kuler'},
#    'low_surface_forms': ['adob kuler', 'kuler adob', 'kuler'],
#    'match_on_tokens': False}),
#  ('KS1207C78FD863K1PG9H',
#   {'skill_name': 'Adobe LiveMotion',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe livemotion'},
#    'low_surface_forms': ['adob livemot', 'livemot adob', 'livemot'],
#    'match_on_tokens': False}),
#  ('ESB08CB83E93B06D3DCB',
#   {'skill_name': 'Adobe Muse',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe muse'},
#    'low_surface_forms': ['adob muse', 'muse adob', 'muse'],
#    'match_on_tokens': False}),
#  ('KS1207G75NS02KCHZL5R',
#   {'skill_name': 'Adobe PageMaker',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe pagemaker'},
#    'low_surface_forms': ['adob pagemak', 'pagemak adob', 'pagemak'],
#    'match_on_tokens': False}),
#  ('KS1207H6MZKGJVMXN5J0',
#   {'skill_name': 'Adobe PageMill',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe pagemill'},
#    'low_surface_forms': ['adob pagemil', 'pagemil adob', 'pagemil'],
#    'match_on_tokens': False}),
#  ('KS1207J74XBJGG0Q9MTK',
#   {'skill_name': 'Adobe PhotoDeluxe',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe photodeluxe'},
#    'low_surface_forms': ['adob photodelux', 'photodelux adob', 'photodelux'],
#    'match_on_tokens': False}),
#  ('KS1207N691JV5KJ3CN99',
#   {'skill_name': 'Adobe RoboHelp',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe robohelp'},
#    'low_surface_forms': ['adob robohelp', 'robohelp adob', 'robohelp'],
#    'match_on_tokens': False}),
#  ('KS1207P647YQRH5RRSFK',
#   {'skill_name': 'Adobe Soundbooth',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe soundbooth'},
#    'low_surface_forms': ['adob soundbooth', 'soundbooth adob', 'soundbooth'],
#    'match_on_tokens': False}),
#  ('ESC27AAFB5C81308A6AA',
#   {'skill_name': 'Adobe XD',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adobe xd'},
#    'low_surface_forms': ['adob xd', 'xd adob', 'xd'],
#    'match_on_tokens': False}),
#  ('KSJ1E41H65BM1QXAN1S9',
#   {'skill_name': 'Advisory Work',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'advisory work'},
#    'low_surface_forms': ['advisori work', 'work advisori', 'advisori'],
#    'match_on_tokens': False}),
#  ('ESB661FD2329B8BA63CF',
#   {'skill_name': 'Adxstudio Portals',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'adxstudio portal'},
#    'low_surface_forms': ['adxstudio portal', 'portal adxstudio', 'adxstudio'],
#    'match_on_tokens': False}),
#  ('KS120946LF2WYQKRND6T',
#   {'skill_name': 'Aerated Lagoon',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aerate lagoon'},
#    'low_surface_forms': ['aerat lagoon', 'lagoon aerat', 'lagoon'],
#    'match_on_tokens': False}),
#  ('KS120965Z7CVPCGS59SH',
#   {'skill_name': 'Aeration Systems',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aeration system'},
#    'low_surface_forms': ['aerat system', 'system aerat', 'aerat'],
#    'match_on_tokens': False}),
#  ('KS120997283GW8KLDSJX',
#   {'skill_name': 'Aerial Refueling',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aerial refueling'},
#    'low_surface_forms': ['aerial refuel', 'refuel aerial', 'refuel'],
#    'match_on_tokens': False}),
#  ('KS1209F660JL3DSR0SM0',
#   {'skill_name': 'Aerobic Organisms',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aerobic organism'},
#    'low_surface_forms': ['aerob organ', 'organ aerob', 'aerob'],
#    'match_on_tokens': False}),
#  ('KS1209G6P94NTW2J0SKG',
#   {'skill_name': 'Aerobiological Engineering',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aerobiological engineering'},
#    'low_surface_forms': ['aerobiolog engin', 'engin aerobiolog', 'aerobiolog'],
#    'match_on_tokens': False}),
#  ('KS1209K76ZTM601J3NPF',
#   {'skill_name': 'Aerodynamic Heating',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aerodynamic heating'},
#    'low_surface_forms': ['aerodynam heat', 'heat aerodynam', 'aerodynam'],
#    'match_on_tokens': False}),
#  ('KS1209G6X0GTRTTTTY9X',
#   {'skill_name': 'Aeromagnetic Survey',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aeromagnetic survey'},
#    'low_surface_forms': ['aeromagnet survey',
#     'survey aeromagnet',
#     'aeromagnet'],
#    'match_on_tokens': False}),
#  ('KS1209K69L6N7PHDGY71',
#   {'skill_name': 'Aerosol Science',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aerosol science'},
#    'low_surface_forms': ['aerosol scienc', 'scienc aerosol', 'aerosol'],
#    'match_on_tokens': False}),
#  ('KS1209T6067D8QX7VM3K',
#   {'skill_name': 'Affirmative Defense',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'affirmative defense'},
#    'low_surface_forms': ['affirm defens', 'defens affirm', 'affirm'],
#    'match_on_tokens': False}),
#  ('KSR43CNSBNTTP538JW4E',
#   {'skill_name': 'African Studies',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'african study'},
#    'low_surface_forms': ['african studi', 'studi african', 'african'],
#    'match_on_tokens': False}),
#  ('ES8844E11D19457EC3AD',
#   {'skill_name': 'Africana Studies',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'africana study'},
#    'low_surface_forms': ['africana studi', 'studi africana', 'africana'],
#    'match_on_tokens': False}),
#  ('ESBBBBACBA39B30028C8',
#   {'skill_name': 'Afrikaans Language',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'afrikaans language'},
#    'low_surface_forms': ['afrikaan languag', 'languag afrikaan', 'afrikaan'],
#    'match_on_tokens': False}),
#  ('KS120T86G254GBWVRD61',
#   {'skill_name': 'Aftermarket Modifications',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aftermarket modification'},
#    'low_surface_forms': ['aftermarket modif',
#     'modif aftermarket',
#     'aftermarket'],
#    'match_on_tokens': False}),
#  ('KSRMPTI9M1EFJRPP8TFN',
#   {'skill_name': 'Agency Law',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'agency law'},
#    'low_surface_forms': ['agenc law', 'law agenc', 'agenc'],
#    'match_on_tokens': False}),
#  ('KS120BB71J8L2SLL2RVW',
#   {'skill_name': 'Agilent ChemStation',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'agilent chemstation'},
#    'low_surface_forms': ['agil chemstat', 'chemstat agil', 'chemstat'],
#    'match_on_tokens': False}),
#  ('KS120BB77VYCCQ1XBQ7N',
#   {'skill_name': 'Agilent VEE (Domain-Specific Programming Language)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'agilent vee'},
#    'low_surface_forms': ['agil vee', 'vee agil', 'vee'],
#    'match_on_tokens': False}),
#  ('KS120B16VXYQQWNJ9M69',
#   {'skill_name': 'Aging Processes',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'age process'},
#    'low_surface_forms': ['age process', 'process age', 'age'],
#    'match_on_tokens': False}),
#  ('ESA2D0620B36194A09BC',
#   {'skill_name': 'Agricultural Tractors',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'agricultural tractor'},
#    'low_surface_forms': ['agricultur tractor',
#     'tractor agricultur',
#     'tractor'],
#    'match_on_tokens': False}),
#  ('KS120C179VVM5SNQ156R',
#   {'skill_name': 'Aimaq Dialects',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aimaq dialect'},
#    'low_surface_forms': ['aimaq dialect', 'dialect aimaq', 'aimaq'],
#    'match_on_tokens': False}),
#  ('KS120CH736SFBPSX4KH3',
#   {'skill_name': 'Aircrack-Ng',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aircrack ng'},
#    'low_surface_forms': ['aircrack ng', 'ng aircrack', 'aircrack'],
#    'match_on_tokens': False}),
#  ('ES9DEB827A600AC2803F',
#   {'skill_name': 'Airline Economics',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'airline economic'},
#    'low_surface_forms': ['airlin econom', 'econom airlin', 'airlin'],
#    'match_on_tokens': False}),
#  ('KS120CP666RZ4YFLDSQV',
#   {'skill_name': 'Airman Leadership',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'airman leadership'},
#    'low_surface_forms': ['airman leadership', 'leadership airman', 'airman'],
#    'match_on_tokens': False}),
#  ('KS120CP6X6F418D5R00V',
#   {'skill_name': 'Airplay SDK (Apple)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'airplay sdk'},
#    'low_surface_forms': ['airplay sdk', 'sdk airplay', 'airplay'],
#    'match_on_tokens': False}),
#  ('KS120CQ779XFR669JY07',
#   {'skill_name': 'Airway Management',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'airway management'},
#    'low_surface_forms': ['airway manag', 'manag airway', 'airway'],
#    'match_on_tokens': False}),
#  ('KS2XMQ8ZOUKBC30CV9D7',
#   {'skill_name': 'Ajax.net',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'ajax net'},
#    'low_surface_forms': ['ajax net', 'net ajax', 'ajax'],
#    'match_on_tokens': False}),
#  ('KSULGPKBWJXVE0WQWTDN',
#   {'skill_name': 'Akka.net',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'akka net'},
#    'low_surface_forms': ['akka net', 'net akka', 'akka'],
#    'match_on_tokens': False}),
#  ('KS120CY70MMPBDBHPJ7M',
#   {'skill_name': 'Akkadian Language',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'akkadian language'},
#    'low_surface_forms': ['akkadian languag', 'languag akkadian', 'akkadian'],
#    'match_on_tokens': False}),
#  ('ES33595A31E4D47C9F2A',
#   {'skill_name': 'Albanian Language',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'albanian language'},
#    'low_surface_forms': ['albanian languag', 'languag albanian', 'albanian'],
#    'match_on_tokens': False}),
#  ('KS120D66SVT2NNXS1P1B',
#   {'skill_name': 'Alfresco ECM',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alfresco ecm'},
#    'low_surface_forms': ['alfresco ecm', 'ecm alfresco', 'ecm'],
#    'match_on_tokens': False}),
#  ('ESF566A21E110A2D0187',
#   {'skill_name': 'Alibaba Cloud',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alibaba cloud'},
#    'low_surface_forms': ['alibaba cloud', 'cloud alibaba', 'alibaba'],
#    'match_on_tokens': False}),
#  ('KS120DD6YX75Z6Q32HL4',
#   {'skill_name': 'Alibre Design',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alibre design'},
#    'low_surface_forms': ['alibr design', 'design alibr', 'alibr'],
#    'match_on_tokens': False}),
#  ('ES5432AD0019D7278E53',
#   {'skill_name': 'Alice Concierge (Software)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alice concierge'},
#    'low_surface_forms': ['alic concierg', 'concierg alic', 'concierg'],
#    'match_on_tokens': False}),
#  ('KS120DG6YR2HPY7NB4R2',
#   {'skill_name': 'Alkalinity Tests',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alkalinity test'},
#    'low_surface_forms': ['alkalin test', 'test alkalin', 'alkalin'],
#    'match_on_tokens': False}),
#  ('KS686CT748YM1F560QGT',
#   {'skill_name': 'Alkylation Units',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alkylation unit'},
#    'low_surface_forms': ['alkyl unit', 'unit alkyl', 'alkyl'],
#    'match_on_tokens': False}),
#  ('KS120DK5YNLR772HPRR6',
#   {'skill_name': 'Allergen Immunotherapy',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'allergen immunotherapy'},
#    'low_surface_forms': ['allergen immunotherapi',
#     'immunotherapi allergen',
#     'immunotherapi'],
#    'match_on_tokens': False}),
#  ('KS120DL69STD76KT4MMV',
#   {'skill_name': 'Allergy Testing',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'allergy testing'},
#    'low_surface_forms': ['allergi test', 'test allergi', 'allergi'],
#    'match_on_tokens': False}),
#  ('KS120DN5YMKCQW4YR002',
#   {'skill_name': 'AlliedWare Plus',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'alliedware plus'},
#    'low_surface_forms': ['alliedwar plu', 'plu alliedwar', 'alliedwar'],
#    'match_on_tokens': False}),
#  ('KS440H26R4BRPZPWJM02',
#   {'skill_name': 'Altap Salamander',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'altap salamander'},
#    'low_surface_forms': ['altap salamand', 'salamand altap', 'salamand'],
#    'match_on_tokens': False}),
#  ('KS120DV6C57571JQPR43',
#   {'skill_name': 'Altera Quartus',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'altera quartus'},
#    'low_surface_forms': ['altera quartu', 'quartu altera', 'quartu'],
#    'match_on_tokens': False}),
#  ('KS120F46C5DT8FCLZHJC',
#   {'skill_name': 'Altium Designer',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'altium designer'},
#    'low_surface_forms': ['altium design', 'design altium', 'altium'],
#    'match_on_tokens': False}),
#  ('KS120F470XQTQML05553',
#   {'skill_name': 'Altix Supercomputers',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'altix supercomputer'},
#    'low_surface_forms': ['altix supercomput',
#     'supercomput altix',
#     'supercomput'],
#    'match_on_tokens': False}),
#  ('KS122XR6XWJ2P92VG0WH',
#   {'skill_name': 'Altova DiffDog (XML)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'abv': 'XML', 'full': 'altova diffdog'},
#    'low_surface_forms': ['altova diffdog', 'diffdog altova', 'diffdog'],
#    'match_on_tokens': False}),
#  ('KS120F66CRJSBVRKQDWP',
#   {'skill_name': 'Aluminium Smelting',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aluminium smelting'},
#    'low_surface_forms': ['aluminium smelt', 'smelt aluminium', 'smelt'],
#    'match_on_tokens': False}),
#  ('KS120F66GN3BLZ5YR2XR',
#   {'skill_name': 'Aluminum Wires',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'aluminum wire'},
#    'low_surface_forms': ['aluminum wire', 'wire aluminum', 'aluminum'],
#    'match_on_tokens': False}),
#  ('ES19D9FD9F838513F644',
#   {'skill_name': 'Amag Symmetry',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amag symmetry'},
#    'low_surface_forms': ['amag symmetri', 'symmetri amag', 'symmetri'],
#    'match_on_tokens': False}),
#  ('KS120FG62DT52Z5GVRG0',
#   {'skill_name': 'Amazon AppStore',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon appstore'},
#    'low_surface_forms': ['amazon appstor', 'appstor amazon', 'appstor'],
#    'match_on_tokens': False}),
#  ('ESFD84A0337F6243EA19',
#   {'skill_name': 'Amazon AppStream',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon appstream'},
#    'low_surface_forms': ['amazon appstream', 'appstream amazon', 'appstream'],
#    'match_on_tokens': False}),
#  ('ES76885391843027C724',
#   {'skill_name': 'Amazon Athena',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon athena'},
#    'low_surface_forms': ['amazon athena', 'athena amazon', 'athena'],
#    'match_on_tokens': False}),
#  ('ESA44B9B1657D479ACDA',
#   {'skill_name': 'Amazon Aurora',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon aurora'},
#    'low_surface_forms': ['amazon aurora', 'aurora amazon', 'aurora'],
#    'match_on_tokens': False}),
#  ('KS120FL623SZDXKZ9F16',
#   {'skill_name': 'Amazon CloudSearch',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon cloudsearch'},
#    'low_surface_forms': ['amazon cloudsearch',
#     'cloudsearch amazon',
#     'cloudsearch'],
#    'match_on_tokens': False}),
#  ('KSSGSFTDVI0J638VZ2RV',
#   {'skill_name': 'Amazon CloudWatch',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon cloudwatch'},
#    'low_surface_forms': ['amazon cloudwatch',
#     'cloudwatch amazon',
#     'cloudwatch'],
#    'match_on_tokens': False}),
#  ('KS120FK5Y76QT8KZ3KYN',
#   {'skill_name': 'Amazon Cloudfront',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon cloudfront'},
#    'low_surface_forms': ['amazon cloudfront',
#     'cloudfront amazon',
#     'cloudfront'],
#    'match_on_tokens': False}),
#  ('ESA479BD58423D255EDE',
#   {'skill_name': 'Amazon Cognito',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon cognito'},
#    'low_surface_forms': ['amazon cognito', 'cognito amazon', 'cognito'],
#    'match_on_tokens': False}),
#  ('ES1862EC684B67B1D846',
#   {'skill_name': 'Amazon Comprehend',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon comprehend'},
#    'low_surface_forms': ['amazon comprehend',
#     'comprehend amazon',
#     'comprehend'],
#    'match_on_tokens': False}),
#  ('ESB376E9EFC518310EC1',
#   {'skill_name': 'Amazon DocumentDB',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon documentdb'},
#    'low_surface_forms': ['amazon documentdb',
#     'documentdb amazon',
#     'documentdb'],
#    'match_on_tokens': False}),
#  ('KS1238D6SC8NVDVCSMRB',
#   {'skill_name': 'Amazon DynamoDB',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon dynamodb'},
#    'low_surface_forms': ['amazon dynamodb', 'dynamodb amazon', 'dynamodb'],
#    'match_on_tokens': False}),
#  ('ES4318AF8441CFE675E3',
#   {'skill_name': 'Amazon ElastiCache',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon elasticache'},
#    'low_surface_forms': ['amazon elasticach',
#     'elasticach amazon',
#     'elasticach'],
#    'match_on_tokens': False}),
#  ('ES7CE467DCFE4B022C97',
#   {'skill_name': 'Amazon GuardDuty',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon guardduty'},
#    'low_surface_forms': ['amazon guardduti', 'guardduti amazon', 'guardduti'],
#    'match_on_tokens': False}),
#  ('ES7A4A3108C91C3F1FA0',
#   {'skill_name': 'Amazon Lex',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon lex'},
#    'low_surface_forms': ['amazon lex', 'lex amazon', 'lex'],
#    'match_on_tokens': False}),
#  ('ESD76BF418EA0D564BB1',
#   {'skill_name': 'Amazon Lightsail',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon lightsail'},
#    'low_surface_forms': ['amazon lightsail', 'lightsail amazon', 'lightsail'],
#    'match_on_tokens': False}),
#  ('ES227FCB2636E0B9BABA',
#   {'skill_name': 'Amazon Macie',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon macie'},
#    'low_surface_forms': ['amazon maci', 'maci amazon', 'maci'],
#    'match_on_tokens': False}),
#  ('KSEEOWT6RSEOH9A387TR',
#   {'skill_name': 'Amazon Marketplace',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon marketplace'},
#    'low_surface_forms': ['amazon marketplac',
#     'marketplac amazon',
#     'marketplac'],
#    'match_on_tokens': False}),
#  ('ES71AAF1A7F799D7DE4C',
#   {'skill_name': 'Amazon Neptune',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon neptune'},
#    'low_surface_forms': ['amazon neptun', 'neptun amazon', 'neptun'],
#    'match_on_tokens': False}),
#  ('ES88CDC76F8938CCB167',
#   {'skill_name': 'Amazon Polly',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon polly'},
#    'low_surface_forms': ['amazon polli', 'polli amazon', 'polli'],
#    'match_on_tokens': False}),
#  ('ES962277805FF207EC3F',
#   {'skill_name': 'Amazon QuickSight',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon quicksight'},
#    'low_surface_forms': ['amazon quicksight',
#     'quicksight amazon',
#     'quicksight'],
#    'match_on_tokens': False}),
#  ('KSZ61G2PSJVHHYDCWD9V',
#   {'skill_name': 'Amazon Redshift',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon redshift'},
#    'low_surface_forms': ['amazon redshift', 'redshift amazon', 'redshift'],
#    'match_on_tokens': False}),
#  ('ES8BB8220C2EEB4EC629',
#   {'skill_name': 'Amazon Rekognition',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon rekognition'},
#    'low_surface_forms': ['amazon rekognit', 'rekognit amazon', 'rekognit'],
#    'match_on_tokens': False}),
#  ('KS440LL6WQMZP5NPVDC6',
#   {'skill_name': 'Amazon SimpleDB',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon simpledb'},
#    'low_surface_forms': ['amazon simpledb', 'simpledb amazon', 'simpledb'],
#    'match_on_tokens': False}),
#  ('ES24C5C98A45F551E85E',
#   {'skill_name': 'Amazon Textract',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'amazon textract'},
# ...
#    'low_surface_forms': ['deck build', 'build deck', 'deck'],
#    'match_on_tokens': False}),
#  ('KS122H46YTP6NDGLYSP7',
#   {'skill_name': 'Decompressive Craniectomy',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'decompressive craniectomy'},
#    'low_surface_forms': ['decompress craniectomi',
#     'craniectomi decompress',
#     'craniectomi'],
#    'match_on_tokens': False}),
#  ('KS122SW6Z9WY1Y7GBMZG',
#   {'skill_name': 'Deductive Database',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deductive database'},
#    'low_surface_forms': ['deduct databas', 'databas deduct', 'deduct'],
#    'match_on_tokens': False}),
#  ('KSBZ9LW988KC56I219SP',
#   {'skill_name': 'Deep Learning',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deep learning'},
#    'low_surface_forms': ['deep learn', 'learn deep', 'deep'],
#    'match_on_tokens': False}),
#  ('KS6860J6S8GBQ6HWJSSV',
#   {'skill_name': 'Deepwater Drilling',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deepwater drilling'},
#    'low_surface_forms': ['deepwat drill', 'drill deepwat', 'deepwat'],
#    'match_on_tokens': False}),
#  ('KS122T45Y2NQ8YZN0LCK',
#   {'skill_name': 'Default Route',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'default route'},
#    'low_surface_forms': ['default rout', 'rout default', 'default'],
#    'match_on_tokens': False}),
#  ('KS122T566P79S5WN9950',
#   {'skill_name': 'Defence Engineering',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'defence engineering'},
#    'low_surface_forms': ['defenc engin', 'engin defenc', 'defenc'],
#    'match_on_tokens': False}),
#  ('KS123736YZW65GZPJ4V8',
#   {'skill_name': 'Deighton DTIMS',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deighton dtim'},
#    'low_surface_forms': ['deighton dtim', 'dtim deighton', 'dtim'],
#    'match_on_tokens': False}),
#  ('KS127ZD746FLLFG4HLJ4',
#   {'skill_name': 'Delcam PowerInspect (3D CAD)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'abv': 'CAD', 'full': 'delcam powerinspect'},
#    'low_surface_forms': ['delcam powerinspect',
#     'powerinspect delcam',
#     'powerinspect'],
#    'match_on_tokens': False}),
#  ('KS127ZK6M2SK4NDR9MWN',
#   {'skill_name': 'Delcam PowerShape',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'delcam powershape'},
#    'low_surface_forms': ['delcam powershap', 'powershap delcam', 'powershap'],
#    'match_on_tokens': False}),
#  ('KSAK8WD3BBOK1CZ3Y6TN',
#   {'skill_name': 'Delimited Text',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'delimited text'},
#    'low_surface_forms': ['delimit text', 'text delimit', 'delimit'],
#    'match_on_tokens': False}),
#  ('ES2374A4ED11D54848A3',
#   {'skill_name': 'Dell Boomi (Integration Platform)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell boomi'},
#    'low_surface_forms': ['dell boomi', 'boomi dell', 'boomi'],
#    'match_on_tokens': False}),
#  ('KS9ZW3LQT4K4H7HMFX4Y',
#   {'skill_name': 'Dell Equallogic',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell equallogic'},
#    'low_surface_forms': ['dell equallog', 'equallog dell', 'equallog'],
#    'match_on_tokens': False}),
#  ('KS1250F73556QG7JBJCT',
#   {'skill_name': 'Dell IDRAC',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell idrac'},
#    'low_surface_forms': ['dell idrac', 'idrac dell', 'idrac'],
#    'match_on_tokens': False}),
#  ('KS127F06D7LY7MSVNLXZ',
#   {'skill_name': 'Dell OptiPlex',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell optiplex'},
#    'low_surface_forms': ['dell optiplex', 'optiplex dell', 'optiplex'],
#    'match_on_tokens': False}),
#  ('KS127ZC60RKVH696CYQZ',
#   {'skill_name': 'Dell PowerConnect',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell powerconnect'},
#    'low_surface_forms': ['dell powerconnect',
#     'powerconnect dell',
#     'powerconnect'],
#    'match_on_tokens': False}),
#  ('KS127ZD6RTLKFNWVWNQ4',
#   {'skill_name': 'Dell PowerEdge',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell poweredge'},
#    'low_surface_forms': ['dell poweredg', 'poweredg dell', 'poweredg'],
#    'match_on_tokens': False}),
#  ('KS127ZL6G6P9C6PTHF14',
#   {'skill_name': 'Dell PowerVault',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dell powervault'},
#    'low_surface_forms': ['dell powervault', 'powervault dell', 'powervault'],
#    'match_on_tokens': False}),
#  ('KS122TL65M8M4K9C7P1L',
#   {'skill_name': 'Deltec Cozmo',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deltec cozmo'},
#    'low_surface_forms': ['deltec cozmo', 'cozmo deltec', 'cozmo'],
#    'match_on_tokens': False}),
#  ('KS122FQ6CG4TJDP0YH8R',
#   {'skill_name': 'Deltek Costpoint',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deltek costpoint'},
#    'low_surface_forms': ['deltek costpoint', 'costpoint deltek', 'costpoint'],
#    'match_on_tokens': False}),
#  ('KS122TL76BPJ5CJXX5Y6',
#   {'skill_name': 'Deltoid Muscle',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deltoid muscle'},
#    'low_surface_forms': ['deltoid muscl', 'muscl deltoid', 'deltoid'],
#    'match_on_tokens': False}),
#  ('KS122TL77JMCNLCBK675',
#   {'skill_name': 'Delusional Disorder',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'delusional disorder'},
#    'low_surface_forms': ['delusion disord', 'disord delusion', 'delusion'],
#    'match_on_tokens': False}),
#  ('KS122TQ6M0QWJNZ7DG14',
#   {'skill_name': 'Demat Account',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'demat account'},
#    'low_surface_forms': ['demat account', 'account demat', 'demat'],
#    'match_on_tokens': False}),
#  ('KS122TQ6TWKRFWMCT9TS',
#   {'skill_name': 'Dementia Care',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dementia care'},
#    'low_surface_forms': ['dementia care', 'care dementia', 'dementia'],
#    'match_on_tokens': False}),
#  ('KS1232W6X9N23MCY6P96',
#   {'skill_name': 'Demilitarized Zones (DMZ)',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'abv': 'DMZ', 'full': 'demilitarize zone'},
#    'low_surface_forms': ['demilitar zone', 'zone demilitar', 'demilitar'],
#    'match_on_tokens': False}),
#  ('KS122TR5WDD167T4XCXC',
#   {'skill_name': 'Democracy Building',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'democracy building'},
#    'low_surface_forms': ['democraci build', 'build democraci', 'democraci'],
#    'match_on_tokens': False}),
#  ('KS7G4956GFZ2FR5Y8YBC',
#   {'skill_name': 'Demonstration Skills',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'demonstration skill'},
#    'low_surface_forms': ['demonstr skill', 'skill demonstr', 'demonstr'],
#    'match_on_tokens': False}),
#  ('KS122TT6PHVJQQ551HZ6',
#   {'skill_name': 'Dendritic Cell',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dendritic cell'},
#    'low_surface_forms': ['dendrit cell', 'cell dendrit', 'dendrit'],
#    'match_on_tokens': False}),
#  ('KSXH3G2TS8DALA9CRXIL',
#   {'skill_name': 'Dependency Walker',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dependency walker'},
#    'low_surface_forms': ['depend walker', 'walker depend', 'walker'],
#    'match_on_tokens': False}),
#  ('KS122V36MK8SS60HVW62',
#   {'skill_name': 'Depletion Regions',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'depletion region'},
#    'low_surface_forms': ['deplet region', 'region deplet', 'deplet'],
#    'match_on_tokens': False}),
#  ('KS120WN5YJQ2HKQ3K2DR',
#   {'skill_name': 'Deposit Accounts',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deposit account'},
#    'low_surface_forms': ['deposit account', 'account deposit', 'deposit'],
#    'match_on_tokens': False}),
#  ('KS122V85Z6Q6Q5R2ZYYB',
#   {'skill_name': 'Derivatives Markets',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'derivative market'},
#    'low_surface_forms': ['deriv market', 'market deriv', 'deriv'],
#    'match_on_tokens': False}),
#  ('KS122VB684MJKJDBPM18',
#   {'skill_name': 'Descaling Agent',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'descale agent'},
#    'low_surface_forms': ['descal agent', 'agent descal', 'descal'],
#    'match_on_tokens': False}),
#  ('KS122VB72XSXQHFT3Y7M',
#   {'skill_name': 'Describing Archives',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'describe archive'},
#    'low_surface_forms': ['describ archiv', 'archiv describ', 'describ'],
#    'match_on_tokens': False}),
#  ('KS122VD774B4F7355CDJ',
#   {'skill_name': 'Design Around',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'design around'},
#    'low_surface_forms': ['design around', 'around design', 'around'],
#    'match_on_tokens': False}),
#  ('KS122W072SGKNR1MQDK1',
#   {'skill_name': 'Destructive Testing',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'destructive testing'},
#    'low_surface_forms': ['destruct test', 'test destruct', 'destruct'],
#    'match_on_tokens': False}),
#  ('KSQPGV2XZO8UMNCC49LK',
#   {'skill_name': 'Detail Oriented',
#    'skill_type': 'Soft Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'detail orient'},
#    'low_surface_forms': ['detail orient', 'orient detail', 'detail'],
#    'match_on_tokens': False}),
#  ('KS122W55X0T3G7SWYX26',
#   {'skill_name': 'Deterministic Methods',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'deterministic method'},
#    'low_surface_forms': ['determinist method',
#     'method determinist',
#     'determinist'],
#    'match_on_tokens': False}),
#  ('KS122WH6VB5HJM0YKXK9',
#   {'skill_name': 'Device Management',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'device management'},
#    'low_surface_forms': ['devic manag', 'manag devic', 'devic'],
#    'match_on_tokens': False}),
#  ('KS122WY78S2LRXF24052',
#   {'skill_name': 'Dhatki Language',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dhatki language'},
#    'low_surface_forms': ['dhatki languag', 'languag dhatki', 'dhatki'],
#    'match_on_tokens': False}),
#  ('ES21F1DAF25A16EB649F',
#   {'skill_name': 'Diabetes Management',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diabetes management'},
#    'low_surface_forms': ['diabet manag', 'manag diabet', 'diabet'],
#    'match_on_tokens': False}),
#  ('KS122X469TVKC2D5BT68',
#   {'skill_name': 'Diabetes Mellitus',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diabete mellitus'},
#    'low_surface_forms': ['diabet mellitu', 'mellitu diabet', 'mellitu'],
#    'match_on_tokens': False}),
#  ('KS122X46DJPG2N57PFR1',
#   {'skill_name': 'Diabetic Ketoacidosis',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diabetic ketoacidosis'},
#    'low_surface_forms': ['diabet ketoacidosi',
#     'ketoacidosi diabet',
#     'ketoacidosi'],
#    'match_on_tokens': False}),
#  ('KS122X566W76YFF0HGYL',
#   {'skill_name': 'Diagnosis Codes',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diagnosis code'},
#    'low_surface_forms': ['diagnosi code', 'code diagnosi', 'diagnosi'],
#    'match_on_tokens': False}),
#  ('KS122X96MLWX8W6L61SH',
#   {'skill_name': 'Diagrammatic Reasoning',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diagrammatic reasoning'},
#    'low_surface_forms': ['diagrammat reason',
#     'reason diagrammat',
#     'diagrammat'],
#    'match_on_tokens': False}),
#  ('KS122X96PNS9B3F1BQR9',
#   {'skill_name': 'Diagramming Software',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diagram software'},
#    'low_surface_forms': ['diagram softwar', 'softwar diagram', 'diagram'],
#    'match_on_tokens': False}),
#  ('KS122XB61PGVCHQVD1LQ',
#   {'skill_name': 'DialameriCA Marketing',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dialamerica marketing'},
#    'low_surface_forms': ['dialamerica market',
#     'market dialamerica',
#     'dialamerica'],
#    'match_on_tokens': False}),
#  ('KS122XF6FVVMT5CH5TJN',
#   {'skill_name': 'Dialog Systems',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dialog system'},
#    'low_surface_forms': ['dialog system', 'system dialog', 'dialog'],
#    'match_on_tokens': False}),
#  ('KS122XF6XFJ52J2JKPVW',
#   {'skill_name': 'Dialogue Marketing',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dialogue marketing'},
#    'low_surface_forms': ['dialogu market', 'market dialogu', 'dialogu'],
#    'match_on_tokens': False}),
#  ('KS4409Q702SS36WMJB28',
#   {'skill_name': 'Diamond Blade',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diamond blade'},
#    'low_surface_forms': ['diamond blade', 'blade diamond', 'diamond'],
#    'match_on_tokens': False}),
#  ('KS122XG60QT0HZ6ZG5X7',
#   {'skill_name': 'Diaphragm Pump',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diaphragm pump'},
#    'low_surface_forms': ['diaphragm pump', 'pump diaphragm', 'diaphragm'],
#    'match_on_tokens': False}),
#  ('KS122XG73SNKYV6NP8CM',
#   {'skill_name': 'Diary Cards',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diary card'},
#    'low_surface_forms': ['diari card', 'card diari', 'diari'],
#    'match_on_tokens': False}),
#  ('ES3A568DE9CFE5A045B1',
#   {'skill_name': 'Diaspora Studies',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diaspora study'},
#    'low_surface_forms': ['diaspora studi', 'studi diaspora', 'diaspora'],
#    'match_on_tokens': False}),
#  ('ES922C9D026CA33BAB50',
#   {'skill_name': 'Dichotomous Key',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'dichotomous key'},
#    'low_surface_forms': ['dichotom key', 'key dichotom', 'dichotom'],
#    'match_on_tokens': False}),
#  ('KS122XY6T7GHWSNLQQZC',
#   {'skill_name': 'Differentiated Services',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'differentiate service'},
#    'low_surface_forms': ['differenti servic',
#     'servic differenti',
#     'differenti'],
#    'match_on_tokens': False}),
#  ('KSTR43U9KTFE1ES4SRYA',
#   {'skill_name': 'Diffie Hellman',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'diffie hellman'},
#    'low_surface_forms': ['diffi hellman', 'hellman diffi', 'hellman'],
#    'match_on_tokens': False}),
#  ('KS122Y06B3TNB86KQ99F',
#   {'skill_name': 'Digestive System',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'digestive system'},
#    'low_surface_forms': ['digest system', 'system digest', 'digest'],
#    'match_on_tokens': False}),
#  ('KS122Y161F3F45CPRZHZ',
#   {'skill_name': 'Digicipher 2',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'digicipher 2'},
#    'low_surface_forms': ['digiciph 2', '2 digiciph', 'digiciph'],
#    'match_on_tokens': False}),
#  ('ESBA5C761891B310C235',
#   {'skill_name': 'Digital Cinematography',
#    'skill_type': 'Hard Skill',
#    'skill_len': 2,
#    'high_surfce_forms': {'full': 'digital cinematography'},
#    'low_surface_forms': ['digit cinematographi',
#     'cinematographi digit',
#     'cinematographi'],
#    'match_on_tokens': False}),
#  ...]

# %%
# clean 2_grams
c=0
dump = []
for i,skill_ in enumerate(a) :
    key,skill=skill_
    for form in skill['low_surface_forms'] :
        if len(form.split(' '))==1 and len(form)>4:
            
            print(skill['low_surface_forms'])
            x = input('skip?')
            if x =='y':
                pass
            else :
                dump.append(key)
            print('------')
# Out:
# ['net reflector', 'reflector net', 'reflector']
# skip?y
# ------
# ['3dvia compos', 'compos 3dvia', '3dvia']
# skip?y
# ------
# ['abc flowchart', 'flowchart abc', 'flowchart']
# skip?y
# ------
# ['abl radiomet', 'radiomet abl', 'radiomet']
# skip?y
# ------
# ['accol workbench', 'workbench accol', 'accol']
# skip?y
# ------
# ['adodc class', 'class adodc', 'adodc']
# skip?y
# ------
# ['adomd net', 'net adomd', 'adomd']
# skip?y
# ------
# ['adp smartcompli', 'smartcompli adp', 'smartcompli']
# skip?y
# ------
# ['adp totalsourc', 'totalsourc adp', 'totalsourc']
# skip?y
# ------
# ['adp vantag', 'vantag adp', 'vantag']
# skip?y
# ------
# ['amd crossfirex', 'crossfirex amd', 'crossfirex']
# skip?y
# ------
# ['ansi icepak', 'icepak ansi', 'icepak']
# skip?y
# ------
# ['ap stylebook', 'stylebook ap', 'stylebook']
# skip?n
# ------
# ['arinc standard', 'standard arinc', 'arinc']
# skip?y
# ------
# ['arm microarchitectur', 'microarchitectur arm', 'microarchitectur']
# skip?n
# ------
# ['aw appsync', 'appsync aw', 'appsync']
# skip?y
# ------
# ['aw cloudform', 'cloudform aw', 'cloudform']
# skip?y
# ------
# ['aw cloudhsm', 'cloudhsm aw', 'cloudhsm']
# skip?y
# ------
# ['aw cloudtrail', 'cloudtrail aw', 'cloudtrail']
# skip?y
# ------
# ['aw codebuild', 'codebuild aw', 'codebuild']
# skip?y
# ------
# ['aw codecommit', 'codecommit aw', 'codecommit']
# skip?y
# ------
# ['aw codedeploy', 'codedeploy aw', 'codedeploy']
# skip?y
# ------
# ['aw codepipelin', 'codepipelin aw', 'codepipelin']
# skip?y
# ------
# ['aw inferentia', 'inferentia aw', 'inferentia']
# skip?y
# ------
# ['aw kinesi', 'kinesi aw', 'kinesi']
# skip?y
# ------
# ['aw sagemak', 'sagemak aw', 'sagemak']
# skip?y
# ------
# ['ab initio', 'initio ab', 'initio']
# skip?y
# ------
# ['abdomin surgeri', 'surgeri abdomin', 'abdomin']
# skip?n
# ------
# ['ableton live', 'live ableton', 'ableton']
# skip?n
# ------
# ['aborigin law', 'law aborigin', 'aborigin']
# skip?n
# ------
# ['abras saw', 'saw abras', 'abras']
# skip?n
# ------
# ['absolut manag', 'manag absolut', 'absolut']
# skip?n
# ------
# ['abstract manag', 'manag abstract', 'abstract']
# skip?n
# ------
# ['accent reduct', 'reduct accent', 'accent']
# skip?n
# ------
# ['accept test', 'test accept', 'accept']
# skip?n
# ------
# ['access stratum', 'stratum access', 'stratum']
# skip?y
# ------
# ['accord net', 'net accord', 'accord']
# skip?n
# ------
# ['accrual account', 'account accrual', 'accrual']
# skip?y
# ------
# ['accru liabil', 'liabil accru', 'accru']
# skip?y
# ------
# ['acid hydrolysi', 'hydrolysi acid', 'hydrolysi']
# skip?y
# ------
# ['acquisit process', 'process acquisit', 'acquisit']
# skip?y
# ------
# ['acryl paint', 'paint acryl', 'acryl']
# skip?y
# ------
# ['actel smartfus', 'smartfus actel', 'smartfus']
# skip?y
# ------
# ['actian vector', 'vector actian', 'actian']
# skip?y
# ------
# ['activest komodo', 'komodo activest', 'komodo']
# skip?y
# ------
# ['activex document', 'document activex', 'activex']
# skip?y
# ------
# ['activ manag', 'manag activ', 'activ']
# skip?n
# ------
# ['actor model', 'model actor', 'actor']
# skip?n
# ------
# ['actuari scienc', 'scienc actuari', 'actuari']
# skip?y
# ------
# ['addict medicin', 'medicin addict', 'addict']
# skip?n
# ------
# ['addit manufactur', 'manufactur addit', 'addit']
# skip?n
# ------
# ['adhes bond', 'bond adhes', 'adhes']
# skip?n
# ------
# ['adhoc queri', 'queri adhoc', 'adhoc']
# skip?n
# ------
# ['adipos tissu', 'tissu adipos', 'adipos']
# skip?y
# ------
# ['adjac matrix', 'matrix adjac', 'adjac']
# skip?y
# ------
# ['adjud process', 'process adjud', 'adjud']
# skip?y
# ------
# ['adlib softwar', 'softwar adlib', 'adlib']
# skip?y
# ------
# ['admin tool', 'tool admin', 'admin']
# skip?n
# ------
# ['admiralti law', 'law admiralti', 'admiralti']
# skip?y
# ------
# ['admiss oper', 'oper admiss', 'admiss']
# skip?y
# ------
# ['adob acrobat', 'acrobat adob', 'acrobat']
# skip?y
# ------
# ['adob authorwar', 'authorwar adob', 'authorwar']
# skip?y
# ------
# ['adob captiv', 'captiv adob', 'captiv']
# skip?y
# ------
# ['adob createpdf', 'createpdf adob', 'createpdf']
# skip?y
# ------
# ['adob encor', 'encor adob', 'encor']
# skip?y
# ------
# ['adob firework', 'firework adob', 'firework']
# skip?y
# ------
# ['adob framemak', 'framemak adob', 'framemak']
# skip?y
# ------
# ['adob freehand', 'freehand adob', 'freehand']
# skip?y
# ------
# ['adob goliv', 'goliv adob', 'goliv']
# skip?y
# ------
# ['adob imagereadi', 'imagereadi adob', 'imagereadi']
# skip?y
# ------
# ['adob incopi', 'incopi adob', 'incopi']
# skip?y
# ------
# ['adob indesign', 'indesign adob', 'indesign']
# skip?y
# ------
# ['adob kuler', 'kuler adob', 'kuler']
# skip?y
# ------
# ['adob livemot', 'livemot adob', 'livemot']
# skip?y
# ------
# ['adob pagemak', 'pagemak adob', 'pagemak']
# skip?y
# ------
# ['adob pagemil', 'pagemil adob', 'pagemil']
# skip?y
# ------
# ['adob photodelux', 'photodelux adob', 'photodelux']
# skip?y
# ------
# ['adob robohelp', 'robohelp adob', 'robohelp']
# skip?y
# ------
# ['adob soundbooth', 'soundbooth adob', 'soundbooth']
# skip?y
# ------
# ['advisori work', 'work advisori', 'advisori']
# skip?y
# ------
# ['adxstudio portal', 'portal adxstudio', 'adxstudio']
# skip?y
# ------
# ['aerat lagoon', 'lagoon aerat', 'lagoon']
# skip?n
# ------
# ['aerat system', 'system aerat', 'aerat']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-dc6a7d27bcf2> in <module>
#       8
#       9             print(skill['low_surface_forms'])
# ---> 10             x = input('skip?')
#      11             if x =='y':
#      12                 pass
#
# ~/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
for key in dump : 
      skills_db[key]['low_surface_forms'] = skills_db[key]['low_surface_forms'][:-1]

# %%
# save
with open('../skillNer/data/skill_db_relax_20.json', 'w', encoding='utf-8') as f:
    json.dump(skills_db, f, ensure_ascii=False, indent=4)

# %%
skills_db['KS1228L6JG2Z7Y9388W1']
# Out:
# {'skill_name': 'Abstract Management',
#  'skill_type': 'Hard Skill',
#  'skill_len': 2,
#  'high_surfce_forms': {'full': 'abstract management'},
#  'low_surface_forms': ['abstract manag', 'manag abstract'],
#  'match_on_tokens': False}

# %%
n_grams = [skills_db[key] for key in skills_db if skills_db[key]['skill_len']>1  ]

# %%
import re
rx = r"\b[A-Z](?=([&.]?))(?:\1[A-Z])+\b"
s =  '.NET Framework 1'

def extract_sub_forms(skill_name):
    return [x.group() for x in re.finditer(rx, skill_name)] 
def remove_btwn_par(str_):
    return re.sub("[\(\[].*?[\)\]]", "", str_)
extract_sub_forms(s)
# Out:
# ['NET']

# %%
c=0
subs=[]
for n_skill in n_grams :
    skill_name = n_skill['skill_name']
    new_skill_name  = remove_btwn_par(skill_name)
    sub_f = extract_sub_forms(new_skill_name)
    if sub_f!=[]:
        print(skill_name)
        print(sub_f)
        print('--------')
        for s in sub_f : 
            subs.append(s)
        c+=1
# Out:
# (American Society For Quality) ASQ Certified
# ['ASQ']
# --------
# .NET Assemblies
# ['NET']
# --------
# .NET Framework
# ['NET']
# --------
# .NET Framework 1
# ['NET']
# --------
# .NET Framework 3
# ['NET']
# --------
# .NET Framework 4
# ['NET']
# --------
# .NET Reflector
# ['NET']
# --------
# .NET Remoting
# ['NET']
# --------
# 10BASE-FL
# ['FL']
# --------
# 10G-PON
# ['PON']
# --------
# 3COM Certified IP Telephony NBX Expert
# ['IP', 'NBX']
# --------
# 3COM Certified IP Telephony VCX Expert
# ['IP', 'VCX']
# --------
# 64-Bit Power PC Processors
# ['PC']
# --------
# 90nm CMOS
# ['CMOS']
# --------
# AAA Protocol (Code Division Multiple Access)
# ['AAA']
# --------
# AAA Server (Authentication Authorization And Accounting)
# ['AAA']
# --------
# AAA Video Games
# ['AAA']
# --------
# ABA Intervention
# ['ABA']
# --------
# ABC FlowCharter
# ['ABC']
# --------
# ABI Solid Sequencing
# ['ABI']
# --------
# ABL Radiometers
# ['ABL']
# --------
# ABR Routers
# ['ABR']
# --------
# AC Motors
# ['AC']
# --------
# AC Power Plugs And Sockets
# ['AC']
# --------
# AC/DC Converters
# ['AC', 'DC']
# --------
# AC/DC Power
# ['AC', 'DC']
# --------
# ACA Instructor Certificate
# ['ACA']
# --------
# ACCOL Workbench
# ['ACCOL']
# --------
# ACCP Certified
# ['ACCP']
# --------
# ACI Concrete Field Testing Technician
# ['ACI']
# --------
# ACI Concrete Laboratory Testing Technician
# ['ACI']
# --------
# ACI Concrete Strength Testing Technician
# ['ACI']
# --------
# ACID Pro
# ['ACID']
# --------
# AD Model Builder (ADMB)
# ['AD']
# --------
# ADATE Systems
# ['ADATE']
# --------
# ADDIE Instructional Design Model
# ['ADDIE']
# --------
# ADHD Tutoring
# ['ADHD']
# --------
# ADHM Construction
# ['ADHM']
# --------
# ADO.NET (Programming Language)
# ['ADO', 'NET']
# --------
# ADO.NET Data Services
# ['ADO', 'NET']
# --------
# ADODC Class
# ['ADODC']
# --------
# ADOMD.NET
# ['ADOMD', 'NET']
# --------
# ADOdb Database Abstraction Library For PHP
# ['PHP']
# --------
# ADP Enterprise
# ['ADP']
# --------
# ADP Reporting
# ['ADP']
# --------
# ADP SmartCompliance
# ['ADP']
# --------
# ADP TotalSource
# ['ADP']
# --------
# ADP Vantage
# ['ADP']
# --------
# ADP Workforce Now
# ['ADP']
# --------
# ADT Security Services
# ['ADT']
# --------
# AEP Netilla Secure Remote Access (Virtual Private Networks)
# ['AEP']
# --------
# AFP Conversion And Indexing Facility (ACIF)
# ['AFP']
# --------
# AGFA Impax 6
# ['AGFA']
# --------
# AISC 360 Specification For Structural Steel Buildings
# ['AISC']
# --------
# ALA Lighting Specialist Certification
# ['ALA']
# --------
# ALM Octane
# ['ALM']
# --------
# ALT Linux
# ['ALT']
# --------
# ALWD Citation Manual
# ['ALWD']
# --------
# AMD Catalyst
# ['AMD']
# --------
# AMD CrossFireX
# ['AMD']
# --------
# AME Accounting Software
# ['AME']
# --------
# AMS Device Management
# ['AMS']
# --------
# AMT Asset Management Software
# ['AMT']
# --------
# AMX Programming
# ['AMX']
# --------
# AN/PRC-148 Multiband Inter/Intra Team Radio (MBITR)
# ['AN', 'PRC']
# --------
# ANCC Certified
# ['ANCC']
# --------
# ANSI C
# ['ANSI']
# --------
# ANSI Escape Codes (Computer Standards)
# ['ANSI']
# --------
# ANSI/ANS Standards
# ['ANSI', 'ANS']
# --------
# ANSI/ASME Y14.1 Standards
# ['ANSI', 'ASME']
# --------
# ANSYS IcePak (Simulation Software)
# ['ANSYS']
# --------
# ANSYS Meshing
# ['ANSYS']
# --------
# AP Stylebook
# ['AP']
# --------
# APA Ethics Code
# ['APA']
# --------
# APC Smart-UPS
# ['APC', 'UPS']
# --------
# API 570 Piping Inspector Certification
# ['API']
# --------
# API Design
# ['API']
# --------
# API Gateway
# ['API']
# --------
# API Management
# ['API']
# --------
# API Oil-Water Separator
# ['API']
# --------
# API Writer
# ['API']
# --------
# APICS Certified Supply Chain Professional
# ['APICS']
# --------
# AR System Administration
# ['AR']
# --------
# ARC Macro Language
# ['ARC']
# --------
# ARINC Standards
# ['ARINC']
# --------
# ARM Architecture
# ['ARM']
# --------
# ARM Architecture Microprocessors
# ['ARM']
# --------
# ARM Microarchitectures
# ['ARM']
# --------
# ASARS-2 Radar System
# ['ASARS']
# --------
# ASC 606 (Revenue Recognition)
# ['ASC']
# --------
# ASC 740 (Accounting For Income Taxes)
# ['ASC']
# --------
# ASC 842 (Lease Accounting Standard)
# ['ASC']
# --------
# ASC X12 Standards
# ['ASC']
# --------
# ASE Advanced Engine Performance Certification
# ['ASE']
# --------
# ASE Auto Maintenance And Light Repair Certification
# ['ASE']
# --------
# ASE Automobile Service Consultant
# ['ASE']
# --------
# ASE Medium-Heavy Truck Certification
# ['ASE']
# --------
# ASE Parts Specialist
# ['ASE']
# --------
# ASIC Programming Language
# ['ASIC']
# --------
# ASME Boiler And Pressure Vessel Code (BPVC)
# ['ASME']
# --------
# ASNT Non-Destructive Tester
# ['ASNT']
# --------
# ASP.NET
# ['ASP', 'NET']
# --------
# ASP.NET Core
# ['ASP', 'NET']
# --------
# ASP.NET Core MVC
# ['ASP', 'NET', 'MVC']
# --------
# ASP.NET Extensions For AJAX
# ['ASP', 'NET', 'AJAX']
# --------
# ASP.NET Fundamentals
# ['ASP', 'NET']
# --------
# ASP.NET Identity
# ['ASP', 'NET']
# --------
# ASP.NET MVC 5
# ['ASP', 'NET', 'MVC']
# --------
# ASP.NET MVC Framework
# ['ASP', 'NET', 'MVC']
# --------
# ASP.NET Razor
# ['ASP', 'NET']
# --------
# ASP.NET Web API
# ['ASP', 'NET', 'API']
# --------
# ASSR Certified
# ['ASSR']
# --------
# ASTM B117 - 11 Standard
# ['ASTM']
# --------
# ATA Over Ethernet
# ['ATA']
# --------
# ATA Packet Interface
# ['ATA']
# --------
# ATL Server
# ['ATL']
# --------
# ATLAS.ti (Qualitative Data Analysis Software)
# ['ATLAS']
# --------
# ATM Adaptation Layer
# ['ATM']
# --------
# ATM Controllers
# ['ATM']
# --------
# AVIXA Certified Technology Specialist
# ['AVIXA']
# --------
# AVL Tree
# ['AVL']
# --------
# AVS Video Editor
# ['AVS']
# --------
# AWS Amplify
# ['AWS']
# --------
# AWS App Mesh
# ['AWS']
# --------
# AWS AppSync
# ['AWS']
# --------
# AWS Auto Scaling
# ['AWS']
# --------
# AWS Backup
# ['AWS']
# --------
# AWS Batch
# ['AWS']
# --------
# AWS CLI (Command Line Interface)
# ['AWS', 'CLI']
# --------
# AWS Certified Advanced Networking Specialty
# ['AWS']
# --------
# AWS Certified Big Data Specialty
# ['AWS']
# --------
# AWS Certified Cloud Practitioner
# ['AWS']
# --------
# AWS Certified DevOps Engineer
# ['AWS']
# --------
# AWS Certified Developer
# ['AWS']
# --------
# AWS Certified Machine Learning Specialty
# ['AWS']
# --------
# AWS Certified Security Specialty
# ['AWS']
# --------
# AWS Certified Solutions Architect
# ['AWS']
# --------
# AWS Certified Solutions Architect Associate
# ['AWS']
# --------
# AWS Certified Solutions Architect Professional
# ['AWS']
# --------
# AWS Certified SysOps Administrator
# ['AWS']
# --------
# AWS CloudFormation
# ['AWS']
# --------
# AWS CloudHSM
# ['AWS']
# --------
# AWS CloudTrail
# ['AWS']
# --------
# AWS CodeBuild
# ['AWS']
# --------
# AWS CodeCommit
# ['AWS']
# --------
# AWS CodeDeploy
# ['AWS']
# --------
# AWS CodePipeline
# ['AWS']
# --------
# AWS Cost Management
# ['AWS']
# --------
# AWS Directory Service
# ['AWS']
# --------
# AWS Elastic Beanstalk
# ['AWS']
# --------
# AWS Elastic MapReduce (EMR)
# ['AWS']
# --------
# AWS Glue
# ['AWS']
# --------
# AWS Identity And Access Management (IAM)
# ['AWS']
# --------
# AWS Inferentia
# ['AWS']
# --------
# AWS Internet of Things (IoT)
# ['AWS']
# --------
# AWS Key Management Service (KMS)
# ['AWS']
# --------
# AWS Kinesis
# ['AWS']
# --------
# AWS Lambda
# ['AWS']
# --------
# AWS SDK
# ['AWS', 'SDK']
# --------
# AWS SageMaker
# ['AWS']
# --------
# AX.25 Protocol
# ['AX']
# --------
# AccuRev SCM
# ['SCM']
# --------
# Act! CRM
# ['CRM']
# --------
# ActiveX Data Objects For The Windows CE Operating System (ADOCE)
# ['CE']
# --------
# Adobe AIR
# ['AIR']
# --------
# Adobe XD
# ['XD']
# --------
# Advanced RISC Computing
# ['RISC']
# --------
# Advanced SCSI Programming Interface
# ['SCSI']
# --------
# Agilent VEE (Domain-Specific Programming Language)
# ['VEE']
# --------
# Agility CMS
# ['CMS']
# --------
# Airplay SDK (Apple)
# ['SDK']
# --------
# Alfresco ECM
# ['ECM']
# --------
# Altia - User Interface Design Tools And GUI Software
# ['GUI']
# --------
# Amadeus CRS
# ['CRS']
# --------
# Amazon API Gateway
# ['API']
# --------
# Amazon MQ
# ['MQ']
# --------
# Amazon Product Advertising API
# ['API']
# --------
# Android NDK
# ['NDK']
# --------
# Android SDK
# ['SDK']
# --------
# Android UI
# ['UI']
# --------
# Angular CLI
# ['CLI']
# --------
# Anjuta IDE (GNOME Developer Tools)
# ['IDE']
# --------
# Any Transport Over MPLS
# ['MPLS']
# --------
# Apache CXF
# ['CXF']
# --------
# Apache Commons OGNL
# ['OGNL']
# --------
# Apache HTTP Server
# ['HTTP']
# --------
# Apache IBATIS
# ['IBATIS']
# --------
# Apache JUDDI
# ['JUDDI']
# --------
# Apache Lucene.NET
# ['NET']
# --------
# Apache POI
# ['POI']
# --------
# Apache SINGA
# ['SINGA']
# --------
# Apple DOS
# ['DOS']
# --------
# Apple IIC
# ['IIC']
# --------
# Apple IIE
# ['IIE']
# --------
# Apple IIGS
# ['IIGS']
# --------
# Apple IOS
# ['IOS']
# --------
# Apple TV
# ['TV']
# --------
# Applesoft BASIC
# ['BASIC']
# --------
# AquaLogic BPM Studio
# ['BPM']
# --------
# Architecture Of Windows NT
# ['NT']
# --------
# Arris CAD
# ['CAD']
# --------
# Assisted GPS
# ['GPS']
# --------
# Atari BASIC
# ['BASIC']
# --------
# Atmel AVR Instruction Set
# ['AVR']
# --------
# AutoCAD DXF
# ['DXF']
# --------
# Automatic Private IP Addressing (APIPA)
# ['IP']
# --------
# Avaya ERS 8600
# ['ERS']
# --------
# Avaya IP Phone 1140e
# ['IP']
# --------
# Avid AAX Plug-In
# ['AAX']
# --------
# Avid DS
# ['DS']
# --------
# Axure RP
# ['RP']
# --------
# Azure API Apps
# ['API']
# --------
# Azure API Management
# ['API']
# --------
# Azure Cosmos DB
# ['DB']
# --------
# Azure MFA
# ['MFA']
# --------
# BASIC 8
# ['BASIC']
# --------
# BASIC A+
# ['BASIC']
# --------
# BASIC Stamp
# ['BASIC']
# --------
# BB FlashBack
# ['BB']
# --------
# BBC BASIC
# ['BBC', 'BASIC']
# --------
# BD LSR II Flow Cytometer
# ['BD', 'LSR', 'II']
# --------
# BD Software C Compiler
# ['BD']
# --------
# BET Theory
# ['BET']
# --------
# BGFS Algorithms
# ['BGFS']
# --------
# BI Launch Pad (Software)
# ['BI']
# --------
# BIPOC Issues
# ['BIPOC']
# --------
# BIRT Project
# ['BIRT']
# --------
# BMC Remedy Action Request System
# ['BMC']
# --------
# BMC User Administration And Provisioning
# ['BMC']
# --------
# BMW N62
# ['BMW']
# --------
# BMW N63
# ['BMW']
# --------
# BOS/360
# ['BOS']
# --------
# BOUML - A Free UML Tool Box
# ['BOUML', 'UML']
# --------
# BS 25999 Standard
# ['BS']
# --------
# BS 5950 Standard
# ['BS']
# --------
# BS 7799 Standard
# ['BS']
# --------
# BS 8110 Standard
# ['BS']
# --------
# BSD Licenses
# ['BSD']
# --------
# BSD Operating System
# ['BSD']
# --------
# BSS Application Part (BSSAP)
# ['BSS']
# --------
# Baan SQL
# ['SQL']
# --------
# Base Station System GPRS Protocol (BSSGP)
# ['GPRS']
# --------
# Berkeley DB
# ['DB']
# --------
# Bio-MEMS
# ['MEMS']
# --------
# BlackBerry OS
# ['OS']
# --------
# Blackbaud CRM
# ['CRM']
# --------
# Blade PC
# ['PC']
# --------
# Blitz BASIC (Object-Oriented Programming Language)
# ['BASIC']
# --------
# BlogEngine.NET
# ['NET']
# --------
# Boris FX
# ['FX']
# --------
# Box API
# ['API']
# --------
# Branched DNA Assay
# ['DNA']
# --------
# Brekeke SIP Servers
# ['SIP']
# --------
# Brushless DC Electric Motor
# ['DC']
# --------
# Bullzip PDF Printer
# ['PDF']
# --------
# Burroughs MCP
# ['MCP']
# --------
# BusinessObjects OLAP Intelligence
# ['OLAP']
# --------
# C POSIX Library
# ['POSIX']
# --------
# C++/CLI
# ['CLI']
# --------
# C++/CX
# ['CX']
# --------
# CA ARCserve (Backup Software)
# ['CA']
# --------
# CA Application Performance Management
# ['CA']
# --------
# CA Clarity
# ['CA']
# --------
# CA DevTest
# ['CA']
# --------
# CA Gen
# ['CA']
# --------
# CA Service Virtualization
# ['CA']
# --------
# CA Software Change Management
# ['CA']
# --------
# CA Test Data Manager
# ['CA']
# --------
# CA Workload Automation Ae
# ['CA']
# --------
# CA-Telon
# ['CA']
# --------
# CA/EZTEST
# ['CA', 'EZTEST']
# --------
# CAD Data Exchange
# ['CAD']
# --------
# CAD Standards
# ['CAD']
# --------
# CAMEL Application Part
# ['CAMEL']
# --------
# CAN Bus
# ['CAN']
# --------
# CAN-SPAM Act
# ['CAN', 'SPAM']
# --------
# CATS Applicant Tracking System
# ['CATS']
# --------
# CBGNA Certified
# ['CBGNA']
# --------
# CBHT-DT
# ['CBHT', 'DT']
# --------
# CBRN Defense
# ['CBRN']
# --------
# CCBSO - Certified Community Bank Security Officer
# ['CCBSO']
# --------
# CCTA Risk Analysis And Management Method (CRAMM)
# ['CCTA']
# --------
# CD Player
# ['CD']
# --------
# CD Publishing
# ['CD']
# --------
# CD-ROMs
# ['CD']
# --------
# CD-RW
# ['CD', 'RW']
# --------
# CDC 6000 Series
# ['CDC']
# --------
# CDETS - Cisco Defect And Enhancement Tracking Systems
# ['CDETS']
# --------
# CDL Class B License
# ['CDL']
# --------
# CDL Class C License
# ['CDL']
# --------
# CDMA Subscriber Identity Module
# ['CDMA']
# --------
# CDNA Libraries
# ['CDNA']
# --------
# CDS ISIS
# ['CDS', 'ISIS']
# --------
# CESG Claims Tested Mark
# ['CESG']
# --------
# CFC Refrigeration Certification
# ['CFC']
# --------
# CFM International CFM56
# ['CFM']
# --------
# CFPPS - Certified Fluid Power Pneumatic Specialist
# ['CFPPS']
# --------
# CGI Scripting
# ['CGI']
# --------
# CIAC Certified Management Consultant
# ['CIAC']
# --------
# CIAC Certified Operations Management
# ['CIAC']
# --------
# CIAC Certified Strategic Leader
# ['CIAC']
# --------
# CIMSPA Affiliate
# ['CIMSPA']
# --------
# CIMSPA Level 2
# ['CIMSPA']
# --------
# CIMSPA Level 3
# ['CIMSPA']
# --------
# CIMSPA Level 4
# ['CIMSPA']
# --------
# CIMSPA Membership
# ['CIMSPA']
# --------
# CIMSPA Personal Trainer
# ['CIMSPA']
# --------
# CIMSPA Practitioner
# ['CIMSPA']
# --------
# CIP System (Stereochemistry)
# ['CIP']
# --------
# CIPD Level 3
# ['CIPD']
# --------
# CIPD Level 5
# ['CIPD']
# --------
# CIPD Level 7
# ['CIPD']
# --------
# CISCO Certified Network Professional - Security
# ['CISCO']
# --------
# CIW Associate Design Specialist
# ['CIW']
# --------
# CIW V5 Database Design Specialists
# ['CIW']
# --------
# CIW Website Management
# ['CIW']
# --------
# CLR Profiler
# ['CLR']
# --------
# CMS Made Simple
# ['CMS']
# --------
# CMS WebEdition
# ['CMS']
# --------
# CMYK Color Model
# ['CMYK']
# --------
# CNAME Record
# ['CNAME']
# --------
# CNC Router
# ['CNC']
# --------
# CNOR Certification
# ['CNOR']
# --------
# CNSS 4013 Recognition
# ['CNSS']
# --------
# COBRA Administration
# ['COBRA']
# --------
# COMSOL Script
# ['COMSOL']
# --------
# CP System
# ['CP']
# --------
# CPN Tools
# ['CPN']
# --------
# CPT Coding
# ['CPT']
# --------
# CPU Design
# ['CPU']
# --------
# CPU Socket
# ['CPU']
# --------
# CPU Time
# ['CPU']
# --------
# CPU-Z
# ['CPU']
# --------
# CRISPR Gene Editing
# ['CRISPR']
# --------
# CRM WebClient UI
# ['CRM', 'UI']
# --------
# CRNBC Verification
# ['CRNBC']
# --------
# CSA CAN3-Z299 Standards
# ['CSA']
# --------
# CSCS Card
# ['CSCS']
# --------
# CSE HTML Validator
# ['CSE', 'HTML']
# --------
# CSLA .NET (Software Development Framework)
# ['CSLA', 'NET']
# --------
# CSS Animations
# ['CSS']
# --------
# CSS Codes
# ['CSS']
# --------
# CSS Flex Box Layout
# ['CSS']
# --------
# CSS Frameworks
# ['CSS']
# --------
# CSSP Analyst
# ['CSSP']
# --------
# CSSP Auditor
# ['CSSP']
# --------
# CSSP Incident Responder
# ['CSSP']
# --------
# CSSP Infrastructure Support
# ['CSSP']
# --------
# CT Pulmonary Angiogram
# ['CT']
# --------
# CTQ Trees (Critical-To-Quality Trees)
# ['CTQ']
# --------
# CUP Parser Generator For Java
# ['CUP']
# --------
# CXFS File System
# ['CXFS']
# --------
# CadSoft EAGLE PCB
# ['EAGLE', 'PCB']
# --------
# Cadence SKILL
# ['SKILL']
# --------
# Camera API
# ['API']
# --------
# Canon EOS DSLR Cameras
# ['EOS', 'DSLR']
# --------
# Canonical XML
# ['XML']
# --------
# Capital IQ (Software)
# ['IQ']
# --------
# Capture CIS
# ['CIS']
# --------
# Carbon-13 NMR
# ['NMR']
# --------
# Cardiac PET
# ['PET']
# --------
# Carefully Controlled Alternative PHP Syntax (CCAPS)
# ['PHP']
# --------
# Carrier-Grade NAT
# ['NAT']
# --------
# CellOpt AFP
# ['AFP']
# --------
# Cerberus FTP Servers
# ['FTP']
# --------
# Certification In IT Project Management
# ['IT']
# --------
# Certified ASC Coder
# ['ASC']
# --------
# Certified Data Management Professional (CDMP) - DAMA
# ['DAMA']
# --------
# Certified EKG/ECG Technician
# ['EKG', 'ECG']
# --------
# Certified IRA Services Professional
# ['IRA']
# --------
# Certified IRB Manager
# ['IRB']
# --------
# Certified In The Governance Of Enterprise IT
# ['IT']
# --------
# Certified Macromedia Flash MX Designer
# ['MX']
# --------
# Certified Macromedia Flash MX Developer
# ['MX']
# --------
# Certified Professional IACUC Administrator
# ['IACUC']
# --------
# Certified U.S. Export Compliance Officer
# ['U.S']
# --------
# Character Encodings In HTML
# ['HTML']
# --------
# CheckPoint PPC (Software)
# ['PPC']
# --------
# Chrome OS
# ['OS']
# --------
# Chromium OS
# ['OS']
# --------
# Chrysler LH Platform
# ['LH']
# --------
# Cisco BPX 8600 Series Switches
# ['BPX']
# --------
# Cisco HDLC
# ['HDLC']
# --------
# Cisco IOS
# ['IOS']
# --------
# Cisco IOS Network Security (IINS)
# ['IOS']
# --------
# Cisco IP Interoperability And Collaboration System (IPICS)
# ['IP']
# --------
# Cisco NAC Appliance
# ['NAC']
# --------
# Cisco PIX
# ['PIX']
# --------
# Cisco PIX Firewall Software
# ['PIX']
# --------
# Cisco Secure PIX Firewall Advanced
# ['PIX']
# --------
# Cisco Small Business SPA500 Series IP Phones
# ['IP']
# --------
# Cisco Systems VPN Client
# ['VPN']
# --------
# Cisco Unified IP Interactive Voice Response
# ['IP']
# --------
# Claris CAD
# ['CAD']
# --------
# Claritas PRIZM
# ['PRIZM']
# --------
# CodeSynthesis XSD/E
# ['XSD']
# --------
# CoffeeCup HTML Editor
# ['HTML']
# --------
# Collaboration Data Objects For Windows NT Servers
# ['NT']
# --------
# Column-Oriented DBMS
# ['DBMS']
# --------
# Common ISDN Application Programming Interface (CAPI)
# ['ISDN']
# --------
# Communication CPU To Application CPU Interface (CAIF)
# ['CPU', 'CPU']
# --------
# CompTIA CASP CE
# ['CASP', 'CE']
# --------
# CompTIA CDIA+
# ['CDIA']
# --------
# CompTIA HTI+
# ['HTI']
# --------
# CompTIA IT Fundamentals
# ['IT']
# --------
# CompTIA Network+ CE
# ['CE']
# --------
# CompTIA RFID+
# ['RFID']
# --------
# CompTIA Security+ CE
# ['CE']
# --------
# Compaq Portable III
# ['III']
# --------
# Compass ERP
# ['ERP']
# --------
# Composite UI Application Block
# ['UI']
# --------
# Consensus CDS Project (Biological Databases)
# ['CDS']
# --------
# Consumer IR
# ['IR']
# --------
# Content Repository API For Java
# ['API']
# --------
# Contivity VPN Client
# ['VPN']
# --------
# Conventional PCI
# ['PCI']
# --------
# Conversational AI
# ['AI']
# --------
# Core API
# ['API']
# --------
# CoreMedia CMS
# ['CMS']
# --------
# Corporate Governance Of ICT
# ['ICT']
# --------
# Criteria API
# ['API']
# --------
# Custom Built PC
# ['PC']
# --------
# DARPA Agent Markup Language (DAML)
# ['DARPA']
# --------
# DAWIA Level 1
# ['DAWIA']
# --------
# DAWIA Level 2
# ['DAWIA']
# --------
# DAWIA Level 3
# ['DAWIA']
# --------
# DAZ Studio
# ['DAZ']
# --------
# DB2 SQL
# ['SQL']
# --------
# DBASE Mac
# ['DBASE']
# --------
# DC Distribution Systems
# ['DC']
# --------
# DC Motors
# ['DC']
# --------
# DCF Interframe Space
# ['DCF']
# --------
# DCRIS - Distributed Customer Records Information System
# ['DCRIS']
# --------
# DCS File Format
# ['DCS']
# --------
# DD-WRT
# ['DD', 'WRT']
# --------
# DDR SDRAM
# ['DDR', 'SDRAM']
# --------
# DEAMS - Defense Enterprise Accounting And Management System
# ['DEAMS']
# --------
# DEC Text Processing Utility
# ['DEC']
# --------
# DECnet Phase IV Control Protocol
# ['IV']
# --------
# DG/L
# ['DG']
# --------
# DG/UX
# ['DG', 'UX']
# --------
# DHCP Snooping
# ['DHCP']
# --------
# DIFMS - Defense Industrial Financial Management Systems
# ['DIFMS']
# --------
# DIGITAL Command Language
# ['DIGITAL']
# --------
# DIP Switch
# ['DIP']
# --------
# DISC Assessments
# ['DISC']
# --------
# DISE Digital Signage Software
# ['DISE']
# --------
# DITA Open Toolkits
# ['DITA']
# --------
# DIVA Software
# ['DIVA']
# --------
# DLL Injection
# ['DLL']
# --------
# DM Over IP (TDMoIP)
# ['DM', 'IP']
# --------
# DME Specialist Certification
# ['DME']
# --------
# DMOZ - The Open Directory Project
# ['DMOZ']
# --------
# DMS Software Reengineering Toolkits
# ['DMS']
# --------
# DNA Computing
# ['DNA']
# --------
# DNA Databases
# ['DNA']
# --------
# DNA Electrophoresis
# ['DNA']
# --------
# DNA Extraction
# ['DNA']
# --------
# DNA Footprinting
# ['DNA']
# --------
# DNA Hybridization
# ['DNA']
# --------
# DNA Ligase (EC 6.5)
# ['DNA']
# --------
# DNA Microarray
# ['DNA']
# --------
# DNA Profiling
# ['DNA']
# --------
# DNA Restriction
# ['DNA']
# --------
# DNA Sequencing
# ['DNA']
# --------
# DNA Splicing
# ['DNA']
# --------
# DNS Spoofing
# ['DNS']
# --------
# DNS Zone
# ['DNS']
# --------
# DNS Zone Transfer
# ['DNS']
# --------
# DNS-Based Blackhole List (DNSBL)
# ['DNS']
# --------
# DO-178B/C (Software Considerations in Airborne Systems and Equipment Certification)
# ['DO']
# --------
# DOCSIS Timing Interface
# ['DOCSIS']
# --------
# DOM Inspector
# ['DOM']
# --------
# DOM Scripting
# ['DOM']
# --------
# DOS Batching
# ['DOS']
# --------
# DOS Memory Management
# ['DOS']
# --------
# DOS Protected Mode Interface (DOS Technology)
# ['DOS']
# --------
# DOS Wedge
# ['DOS']
# --------
# DOS/360 And Successors
# ['DOS']
# --------
# DR-DOS
# ['DR', 'DOS']
# --------
# DSL Filter
# ['DSL']
# --------
# DSL Modems
# ['DSL']
# --------
# DSRP Theories
# ['DSRP']
# --------
# DSS / Defense Central Index Of Investigations
# ['DSS']
# --------
# DUAL Table
# ['DUAL']
# --------
# DVB - Digital Video Broadcasting
# ['DVB']
# --------
# DVB-H
# ['DVB']
# --------
# DVD Decrypter
# ['DVD']
# --------
# DVD Flick
# ['DVD']
# --------
# DVD Ripper
# ['DVD']
# --------
# DVD Shrink
# ['DVD']
# --------
# DVD Studio Pro
# ['DVD']
# --------
# DVD-R
# ['DVD']
# --------
# DVD-RW
# ['DVD', 'RW']
# --------
# DVD-Video
# ['DVD']
# --------
# DWG TrueView
# ['DWG']
# --------
# DYNIX/Ptx
# ['DYNIX']
# --------
# Dassault Syst Mes DELMIA (Software)
# ['DELMIA']
# --------
# Data General AOS
# ['AOS']
# --------
# Data General RDOS
# ['RDOS']
# --------
# Data ONTAP (Server Appliance)
# ['ONTAP']
# --------
# DataTransfer Workbench SAP
# ['SAP']
# --------
# Datacom/DB
# ['DB']
# --------
# Deighton DTIMS
# ['DTIMS']
# --------
# Dell IDRAC
# ['IDRAC']
# --------
# Diagnosis Of HIV/AIDS
# ['HIV', 'AIDS']
# --------
# Differential GPS
# ['GPS']
# --------
# Digital ICE
# ['ICE']
# --------
# Distributed GIS
# ['GIS']
# --------
# Distributed Resource Management Application API (DRMAA)
# ['API']
# --------
# Domino Internet Inter-ORB Protocol (DIIOP)
# ['ORB']
# --------
# Domino XML Language
# ['XML']
# --------
# DragonFly BSD
# ['BSD']
# --------
# Dual-Ported RAM
# ['RAM']
# --------
# Dundas BI
# ['BI']
# --------
# Dynamic DNS (Domain Name System)
# ['DNS']
# --------
# Dynamic HTML
# ['HTML']
# --------
# Dynamic Photo HDR
# ['HDR']
# --------
# Dynamic UI
# ['UI']
# --------
# E-UTRA
# ['UTRA']
# --------
# EBIOS Risk Evaluation
# ['EBIOS']
# --------
# EC Council Certified Secure Programmer
# ['EC']
# --------
# EC Council Certified Security Analyst
# ['EC']
# --------
# ECC Memory
# ['ECC']
# --------
# ECCMA Open Technical Dictionary (EOTD)
# ['ECCMA']
# --------
# ECI Empower (Human Capital Management Software)
# ['ECI']
# --------
# ECMAScript For XML
# ['XML']
# --------
# EFTP Protocol
# ['EFTP']
# --------
# ELODIE Spectrograph
# ['ELODIE']
# --------
# EM Client
# ['EM']
# --------
# EM Simulation Software
# ['EM']
# --------
# EMC Atmos
# ['EMC']
# --------
# EMC Clariion
# ['EMC']
# --------
# EMC Cloud Computing
# ['EMC']
# --------
# EMC Implementation Engineer Certification
# ['EMC']
# --------
# EMC Invista
# ['EMC']
# --------
# EMC NetWorker
# ['EMC']
# --------
# EMC Proven Professional
# ['EMC']
# --------
# EMC Proven Professional Certification
# ['EMC']
# --------
# EMC Storage Administrator Certification
# ['EMC']
# --------
# EMC Storage Technologist Certification
# ['EMC']
# --------
# EMC Technician
# ['EMC']
# --------
# EMC Technology Architect Certification
# ['EMC']
# --------
# EMC Winton-Engined Switchers
# ['EMC']
# --------
# EMCO MSI Package Builder
# ['EMCO', 'MSI']
# --------
# EMCO Remote Installer
# ['EMCO']
# --------
# EN 1993 Building Codes
# ['EN']
# --------
# EPA 608 Technician Certification
# ['EPA']
# --------
# EPA Type I Certification
# ['EPA']
# --------
# EPA Type II Certification
# ['EPA', 'II']
# --------
# EPA Universal Certification
# ['EPA']
# --------
# EPI Info
# ['EPI']
# --------
# EPI Maps
# ['EPI']
# --------
# ERD Commander (Software)
# ['ERD']
# --------
# ERP System Selection Methodology
# ['ERP']
# --------
# ESD Simulator
# ['ESD']
# --------
# ESET NOD32 Antivirus
# ['ESET']
# --------
# ESPRIT AutoCAD
# ['ESPRIT']
# --------
# ETS-NOCV
# ['ETS', 'NOCV']
# --------
# EXC Codes
# ['EXC']
# --------
# EXEC 2
# ['EXEC']
# --------
# EZ Publish
# ['EZ']
# --------
# Ebay API
# ['API']
# --------
# Eclipse CDT Project Development Tooling
# ['CDT']
# --------
# Eclipse PPM Software
# ['PPM']
# --------
# Electric VLSI Design System
# ['VLSI']
# --------
# Electrical CAD
# ['CAD']
# --------
# Electronic Filing ID Numbers
# ['ID']
# --------
# Embedded HTTP Server
# ['HTTP']
# --------
# Embedded RDF (XML-Based Standards)
# ['RDF']
# --------
# Embedded SQL
# ['SQL']
# --------
# Enhanced Data Rates For GSM Evolution
# ['GSM']
# --------
# Enhanced GPS
# ['GPS']
# --------
# Enterprise Value/EBITDA
# ['EBITDA']
# --------
# Epic ADT
# ['ADT']
# --------
# Epic ASAP
# ['ASAP']
# --------
# Epiphany CRM
# ['CRM']
# --------
# Epson QX-10
# ['QX']
# --------
# Esophageal PH Monitoring
# ['PH']
# --------
# Ethernet Over PDH
# ['PDH']
# --------
# Ethernet Over SDH
# ['SDH']
# --------
# Evolved HSPA
# ['HSPA']
# --------
# Executable UML
# ['UML']
# --------
# Exponent CMS
# ['CMS']
# --------
# Ext JS
# ['JS']
# --------
# Ext.NET
# ['NET']
# --------
# Extended SMTP
# ['SMTP']
# --------
# FAA First Class Medical Certificate
# ['FAA']
# --------
# FAA Second Class Medical Certificate
# ['FAA']
# --------
# FASB 133
# ['FASB']
# --------
# FAST ESP
# ['FAST', 'ESP']
# --------
# FASTA Format
# ['FASTA']
# --------
# FCC Declaration Of Conformity
# ['FCC']
# --------
# FCC Electronic Document Management System
# ['FCC']
# --------
# FCC Regulations
# ['FCC']
# --------
# FDA Food Safety Modernization Act
# ['FDA']
# --------
# FIDIC Templates
# ['FIDIC']
# --------
# FIFO And LIFO Accounting
# ['FIFO', 'LIFO']
# --------
# FIN 48
# ['FIN']
# --------
# FL Studio
# ['FL']
# --------
# FLUKA Particle Transport Code (Fortran Software)
# ['FLUKA']
# --------
# FM Broadcasting
# ['FM']
# --------
# FOUNDATION Fieldbus
# ['FOUNDATION']
# --------
# FS Design Studio
# ['FS']
# --------
# Fabric OS
# ['OS']
# --------
# Facebook Graph API
# ['API']
# --------
# FarCry CMS
# ['CMS']
# --------
# Ferroelectric RAM
# ['RAM']
# --------
# Fibre Channel Over IP
# ['IP']
# --------
# Flash CMS
# ['CMS']
# --------
# Flexible AC Transmission Systems
# ['AC']
# --------
# Fluorine-19 NMR
# ['NMR']
# --------
# Fuse ESB
# ['ESB']
# --------
# GALS Screen
# ['GALS']
# --------
# GD Graphics Libraries
# ['GD']
# --------
# GFI Network Server Monitor
# ['GFI']
# --------
# GIAC Assessing and Auditing Wireless Networks
# ['GIAC']
# --------
# GIAC Certifications
# ['GIAC']
# --------
# GIAC Certified Enterprise Defender (GCED)
# ['GIAC']
# --------
# GIAC Certified Firewall Analyst
# ['GIAC']
# --------
# GIAC Certified Forensic Examiner
# ['GIAC']
# --------
# GIAC Certified Forensics Analyst
# ['GIAC']
# --------
# GIAC Certified ISO-17799 Specialist
# ['GIAC', 'ISO']
# --------
# GIAC Certified Incident Handler
# ['GIAC']
# --------
# GIAC Certified Intrusion Analyst
# ['GIAC']
# --------
# GIAC Certified Security Consultant
# ['GIAC']
# --------
# GIAC Certified Unix Security Administrator
# ['GIAC']
# --------
# GIAC Certified Windows Security Administrator
# ['GIAC']
# --------
# GIAC Cutting Edge Hacking Techniques
# ['GIAC']
# --------
# GIAC Cyber Threat Intelligence
# ['GIAC']
# --------
# GIAC Exploit Researcher and Advanced Penetration Tester
# ['GIAC']
# --------
# GIAC Fundamentals Of Information Security Policies
# ['GIAC']
# --------
# GIAC Global Industrial Cyber Security Professional
# ['GIAC']
# --------
# GIAC HIPPA Security Implementation
# ['GIAC', 'HIPPA']
# --------
# GIAC Information Security Fundamentals
# ['GIAC']
# --------
# GIAC Information Security Officer
# ['GIAC']
# --------
# GIAC Information Security Professional
# ['GIAC']
# --------
# GIAC Intrusion Prevention
# ['GIAC']
# --------
# GIAC Legal Issues In Information Technologies
# ['GIAC']
# --------
# GIAC Network Forensic Analyst
# ['GIAC']
# --------
# GIAC Payment Card Industry
# ['GIAC']
# --------
# GIAC Penetration Tester
# ['GIAC']
# --------
# GIAC Reverse Engineering Malware
# ['GIAC']
# --------
# GIAC Secure Internet Presence
# ['GIAC']
# --------
# GIAC Securing Oracle Certification
# ['GIAC']
# --------
# GIAC Security Audit Essentials
# ['GIAC']
# --------
# GIAC Security Essentials Certification
# ['GIAC']
# --------
# GIAC Security Leadership Certification
# ['GIAC']
# --------
# GIAC Security Policy And Awareness
# ['GIAC']
# --------
# GIAC Web Application Defender
# ['GIAC']
# --------
# GIAC Web Application Penetration Tester
# ['GIAC']
# --------
# GIAC Web Application Security
# ['GIAC']
# --------
# GIAC Windows Security Administrator Certification
# ['GIAC']
# --------
# GIF Animation
# ['GIF']
# --------
# GIS Applications
# ['GIS']
# --------
# GIS Certificate
# ['GIS']
# --------
# GIS Mapping
# ['GIS']
# --------
# GNAT Programming Studio
# ['GNAT']
# --------
# GNOME Terminal
# ['GNOME']
# --------
# GNSS Augmentation
# ['GNSS']
# --------
# GNU ADNS
# ['GNU', 'ADNS']
# --------
# GNU Aspell
# ['GNU']
# --------
# GNU Assembler
# ['GNU']
# --------
# GNU Autoconf
# ['GNU']
# --------
# GNU Binutils
# ['GNU']
# --------
# GNU Build Systems
# ['GNU']
# --------
# GNU C Libraries
# ['GNU']
# --------
# GNU Cflow (C Programming Language)
# ['GNU']
# --------
# GNU Circuit Analysis Package
# ['GNU']
# --------
# GNU Cobol
# ['GNU']
# --------
# GNU Common Lisp
# ['GNU']
# --------
# GNU Compiler Collection
# ['GNU']
# --------
# GNU Compiler For Java
# ['GNU']
# --------
# GNU Debuggers
# ['GNU']
# --------
# GNU Emacs
# ['GNU']
# --------
# GNU Gatekeeper
# ['GNU']
# --------
# GNU Image Manipulation Program (GIMP)
# ['GNU']
# --------
# GNU Lesser General Public Licensing
# ['GNU']
# --------
# GNU Libtool
# ['GNU']
# --------
# GNU Linear Programming Kit
# ['GNU']
# --------
# GNU Linker
# ['GNU']
# --------
# GNU Mailman
# ['GNU']
# --------
# GNU MathProg (GNU Project Software)
# ['GNU']
# --------
# GNU Multiple Precision Arithmetic Libraries
# ['GNU']
# --------
# GNU Octave (GNU Project Software)
# ['GNU']
# --------
# GNU Privacy Guard
# ['GNU']
# --------
# GNU Prolog
# ['GNU']
# --------
# GNU Radio
# ['GNU']
# --------
# GNU Scientific Libraries
# ['GNU']
# --------
# GNU Toolchain
# ['GNU']
# --------
# GNU Xnee (Automation Software)
# ['GNU']
# --------
# GNU Zebra
# ['GNU']
# --------
# GOST Standards
# ['GOST']
# --------
# GPE Palmtop Environment (X Window System)
# ['GPE']
# --------
# GPRS Core Networks
# ['GPRS']
# --------
# GPRS Roaming Exchange
# ['GPRS']
# --------
# GPRS Tunnelling Protocol
# ['GPRS']
# --------
# GPS EXchange Format
# ['GPS']
# --------
# GPS Navigation Devices
# ['GPS']
# --------
# GPS Navigation Software
# ['GPS']
# --------
# GPS Signals
# ['GPS']
# --------
# GPS Tracking Unit
# ['GPS']
# --------
# GSM 03.38 Character Set
# ['GSM']
# --------
# GSM 03.40 Standard
# ['GSM']
# --------
# GSM 03.48 Protocol
# ['GSM']
# --------
# GSM Frequency Bands
# ['GSM']
# --------
# GSM Protocols
# ['GSM']
# --------
# GSM Radio Access Networks
# ['GSM']
# --------
# GSM Services
# ['GSM']
# --------
# GT-SUITE (Simulation Software)
# ['GT', 'SUITE']
# --------
# GT.M
# ['GT']
# --------
# GTK Sharp
# ['GTK']
# --------
# GUI Designer
# ['GUI']
# --------
# GUI Editor
# ['GUI']
# --------
# GUI Testing Tools
# ['GUI']
# --------
# GUS Reporter Systems
# ['GUS']
# --------
# GW-BASIC
# ['GW', 'BASIC']
# --------
# GWD Text Editor
# ['GWD']
# --------
# Galileo CRS
# ['CRS']
# --------
# GeneXpert MTB/RIF
# ['MTB', 'RIF']
# --------
# Global XML Web Services Architecture (GXA)
# ['XML']
# --------
# Google Chart API
# ['API']
# --------
# Google Gadgets API
# ['API']
# --------
# Google IME
# ['IME']
# --------
# Graphics API
# ['API']
# --------
# H.262/MPEG-2 Part 2
# ['MPEG']
# --------
# H.264/MPEG-4 AVC
# ['MPEG', 'AVC']
# --------
# HACCP Certified Auditor
# ['HACCP']
# --------
# HAZWOPER Certification
# ['HAZWOPER']
# --------
# HEC-HMS (Hydrologic Modeling System)
# ['HEC', 'HMS']
# --------
# HEC-RAS
# ['HEC', 'RAS']
# --------
# HELLP Syndrome
# ['HELLP']
# --------
# HFS Plus
# ['HFS']
# --------
# HIPAA Eligibility Transaction System
# ['HIPAA']
# --------
# HIPPS Codes
# ['HIPPS']
# --------
# HIV Testing
# ['HIV']
# --------
# HMMWV Objective Gunner Protection Kit
# ['HMMWV']
# --------
# HOOPS 3D Graphics Systems
# ['HOOPS']
# --------
# HP 3000
# ['HP']
# --------
# HP 9000
# ['HP']
# --------
# HP 9000 Servers
# ['HP']
# --------
# HP Accredited Integration Specialist
# ['HP']
# --------
# HP Accredited Platform Specialist
# ['HP']
# --------
# HP Application Lifecycle Management (ALM)
# ['HP']
# --------
# HP BASIC
# ['HP', 'BASIC']
# --------
# HP BASIC For OpenVMS
# ['HP', 'BASIC']
# --------
# HP BladeSystems
# ['HP']
# --------
# HP Certified System Administrator
# ['HP']
# --------
# HP Certified Systems Engineer
# ['HP']
# --------
# HP Client Automation Software
# ['HP']
# --------
# HP Cloud
# ['HP']
# --------
# HP Cloud Service Automation Software
# ['HP']
# --------
# HP Command Line Interface (CLI)
# ['HP']
# --------
# HP Compaq TC1100
# ['HP']
# --------
# HP Comprehensive Defective Material Retention (CDMR)
# ['HP']
# --------
# HP Computers
# ['HP']
# --------
# HP DDMI
# ['HP', 'DDMI']
# --------
# HP Data Protector
# ['HP']
# --------
# HP ExpertOne
# ['HP']
# --------
# HP Hard Partitioning
# ['HP']
# --------
# HP Information Management Software
# ['HP']
# --------
# HP Integrity Servers (HP Servers)
# ['HP']
# --------
# HP Integrity Virtual Machines
# ['HP']
# --------
# HP Linux Imaging And Printing
# ['HP']
# --------
# HP Loadrunner
# ['HP']
# --------
# HP Master Accredited Systems Engineer
# ['HP']
# --------
# HP MediaSmart Servers
# ['HP']
# --------
# HP Multi-Programming Executive
# ['HP']
# --------
# HP Neoview
# ['HP']
# --------
# HP OpenCall
# ['HP']
# --------
# HP OpenView
# ['HP']
# --------
# HP Operations Manager
# ['HP']
# --------
# HP Pascal
# ['HP']
# --------
# HP Personal Notebooks
# ['HP']
# --------
# HP Photosmart
# ['HP']
# --------
# HP Printers
# ['HP']
# --------
# HP Proliant
# ['HP']
# --------
# HP Quality Centers
# ['HP']
# --------
# HP Quicktest Professional
# ['HP']
# --------
# HP Scannings
# ['HP']
# --------
# HP Servers
# ['HP']
# --------
# HP Service Manager Software
# ['HP']
# --------
# HP SiteScope
# ['HP']
# --------
# HP Software
# ['HP']
# --------
# HP Storageworks
# ['HP']
# --------
# HP Storageworks XP
# ['HP', 'XP']
# --------
# HP Systems Insight Manager
# ['HP']
# --------
# HP TRIM Records Management Systems
# ['HP', 'TRIM']
# --------
# HP Thin Clients
# ['HP']
# --------
# HP TouchPad
# ['HP']
# --------
# HP Vectra
# ['HP']
# --------
# HP Virtual Connect
# ['HP']
# --------
# HP Web Jetadmin
# ['HP']
# --------
# HP WebInspect
# ['HP']
# --------
# HP Winrunner
# ['HP']
# --------
# HP Workstations
# ['HP']
# --------
# HP-UX
# ['HP', 'UX']
# --------
# HP/OpenText Exstream
# ['HP']
# --------
# HPC Catalysts
# ['HPC']
# --------
# HR Consulting
# ['HR']
# --------
# HR Data Warehouse
# ['HR']
# --------
# HTML 4.0 Certification
# ['HTML']
# --------
# HTML Abstraction Markup Language
# ['HTML']
# --------
# HTML Application
# ['HTML']
# --------
# HTML Components
# ['HTML']
# --------
# HTML Controls
# ['HTML']
# --------
# HTML Document Object Models
# ['HTML']
# --------
# HTML Editor
# ['HTML']
# --------
# HTML Formatting
# ['HTML']
# --------
# HTML Generation
# ['HTML']
# --------
# HTML Reports
# ['HTML']
# --------
# HTML Scripting
# ['HTML']
# --------
# HTML Tables
# ['HTML']
# --------
# HTML Tidy
# ['HTML']
# --------
# HTML-Kit
# ['HTML']
# --------
# HTMLx - JavaScript On The Server For .NET
# ['NET']
# --------
# HTTP Cookie
# ['HTTP']
# --------
# HTTP File Servers
# ['HTTP']
# --------
# HTTP Live Streaming
# ['HTTP']
# --------
# HTTP Tunnel
# ['HTTP']
# --------
# HUD-VASH (Veteran Affairs Supportive Housing)
# ['HUD', 'VASH']
# --------
# HVAC Automation Systems
# ['HVAC']
# --------
# HVAC Certification
# ['HVAC']
# --------
# HVAC Controls
# ['HVAC']
# --------
# HVAC Estimating
# ['HVAC']
# --------
# HVAC Mini-Split Systems
# ['HVAC']
# --------
# HVAC Package Units
# ['HVAC']
# --------
# HVAC Rooftop Units
# ['HVAC']
# --------
# HVAC Split Systems
# ['HVAC']
# --------
# Handheld PC
# ['PC']
# --------
# Health Systems And Policy Monitor - HSPM
# ['HSPM']
# --------
# Heartsaver CPR AED
# ['CPR', 'AED']
# --------
# Hepa-IC (ELISA Assays For HCC Detection)
# ['IC']
# --------
# Hierarchical And Recursive Queries In SQL
# ['SQL']
# --------
# High-Speed SECS Message Services
# ['SECS']
# --------
# Hippo CMS
# ['CMS']
# --------
# Home Theater PC
# ['PC']
# --------
# Hyper SQL Database (HSQLDB)
# ['SQL']
# --------
# I.MX (ARM Architecture)
# ['MX']
# --------
# IADC WellCap Supervisor
# ['IADC']
# --------
# IAE V2500 Engine
# ['IAE']
# --------
# IAM Level I Certification
# ['IAM']
# --------
# IAM Level II Certification
# ['IAM', 'II']
# --------
# IAM Level III Certification
# ['IAM', 'III']
# --------
# IAPMO Mechanical Inspection
# ['IAPMO']
# --------
# IAS 39
# ['IAS']
# --------
# IAT Level I Certification
# ['IAT']
# --------
# IAT Level II Certification
# ['IAT', 'II']
# --------
# IAT Level III Certification
# ['IAT', 'III']
# --------
# IBM - IMS High Availability Large Database
# ['IBM', 'IMS']
# --------
# IBM - Personal Communications
# ['IBM']
# --------
# IBM - Tivoli Change And Configuration Management Database
# ['IBM']
# --------
# IBM 3081
# ['IBM']
# --------
# IBM 3584
# ['IBM']
# --------
# IBM 3745
# ['IBM']
# --------
# IBM 37xx
# ['IBM']
# --------
# IBM 4300
# ['IBM']
# --------
# IBM 4690 Operating Systems
# ['IBM']
# --------
# IBM AIX
# ['IBM', 'AIX']
# --------
# IBM Advanced Peer-To-Peer Networking
# ['IBM']
# --------
# IBM Advanced Program-To-Program Communications
# ['IBM']
# --------
# IBM Aggregate Backup And Recovery Systems
# ['IBM']
# --------
# IBM Aptiva
# ['IBM']
# --------
# IBM BASIC
# ['IBM', 'BASIC']
# --------
# IBM Basic Assembly Language And Successors
# ['IBM']
# --------
# IBM Blade
# ['IBM']
# --------
# IBM Bluemix
# ['IBM']
# --------
# IBM Blueworks Live
# ['IBM']
# --------
# IBM Business Process Manager (BPM)
# ['IBM']
# --------
# IBM Business Systems
# ['IBM']
# --------
# IBM C2T
# ['IBM']
# --------
# IBM CMS Pipelines
# ['IBM', 'CMS']
# --------
# IBM Certified Instructor
# ['IBM']
# --------
# IBM Certified SOA Associate
# ['IBM', 'SOA']
# --------
# IBM Certified SOA Solution Designer
# ['IBM', 'SOA']
# --------
# IBM Certified System Administrator
# ['IBM']
# --------
# IBM Cgidev2
# ['IBM']
# --------
# IBM Cloud Computing
# ['IBM']
# --------
# IBM Cognos Business Intelligence
# ['IBM']
# --------
# IBM Cognos TM1
# ['IBM']
# --------
# IBM Common User Access
# ['IBM']
# --------
# IBM Computers
# ['IBM']
# --------
# IBM Configuration Management Version Control
# ['IBM']
# --------
# IBM Connections
# ['IBM']
# --------
# IBM DB2
# ['IBM']
# --------
# IBM DB2 DProp
# ['IBM']
# --------
# IBM DFSMS
# ['IBM', 'DFSMS']
# --------
# IBM DISOSS
# ['IBM', 'DISOSS']
# --------
# IBM Data Studio
# ['IBM']
# --------
# IBM DeveloperWorks
# ['IBM']
# --------
# IBM Director
# ['IBM']
# --------
# IBM Disk Storage Systems
# ['IBM']
# --------
# IBM ES/9000 Family
# ['IBM', 'ES']
# --------
# IBM ESA/390
# ['IBM', 'ESA']
# --------
# IBM EServers
# ['IBM']
# --------
# IBM Electric Typewriter
# ['IBM']
# --------
# IBM Entity Analytics Solutions (EAS)
# ['IBM']
# --------
# IBM Fibre Connection (FICON) Protocol
# ['IBM']
# --------
# IBM Forms Server
# ['IBM']
# --------
# IBM General Parallel File Systems
# ['IBM']
# --------
# IBM Generalized Markup Language
# ['IBM']
# --------
# IBM HTTP Servers
# ['IBM', 'HTTP']
# --------
# IBM Hardware Management Console
# ['IBM']
# --------
# IBM High Availability Cluster Multiprocessing
# ['IBM']
# --------
# IBM High Level Assembler
# ['IBM']
# --------
# IBM I
# ['IBM']
# --------
# IBM IKJEFT01
# ['IBM']
# --------
# IBM ILOG CPLEX Optimization Studio (CPLEX)
# ['IBM', 'ILOG', 'CPLEX']
# --------
# IBM InfoPrint Manager
# ['IBM']
# --------
# IBM InfoSphere (ETL Tools)
# ['IBM']
# --------
# IBM InfoSphere DataStage
# ['IBM']
# --------
# IBM Information Management System
# ['IBM']
# --------
# IBM Informix
# ['IBM']
# --------
# IBM Informix Dynamic Server
# ['IBM']
# --------
# IBM Informix ESQL/C
# ['IBM', 'ESQL']
# --------
# IBM Informix-4GL
# ['IBM']
# --------
# IBM Intelligent Printer Data Stream (Computer Printing)
# ['IBM']
# --------
# IBM LAN Servers
# ['IBM', 'LAN']
# --------
# IBM LU6.2
# ['IBM']
# --------
# IBM Lotus Domino
# ['IBM']
# --------
# IBM Lotus Forms
# ['IBM']
# --------
# IBM Lotus Freelance Graphics
# ['IBM']
# --------
# IBM Lotus INotes
# ['IBM']
# --------
# IBM Lotus QuickPlace
# ['IBM']
# --------
# IBM Lotus Quickr
# ['IBM']
# --------
# IBM Lotus SmartSuite
# ['IBM']
# --------
# IBM Lotus Symphony
# ['IBM']
# --------
# IBM Lotus Word Pro
# ['IBM']
# --------
# IBM MTCS
# ['IBM', 'MTCS']
# --------
# IBM Magstar ERP
# ['IBM', 'ERP']
# --------
# IBM Mainframe
# ['IBM']
# --------
# IBM Mainframe Utility Programs
# ['IBM']
# --------
# IBM Master Data Management
# ['IBM']
# --------
# IBM Maximo
# ['IBM']
# --------
# IBM Microprocessors
# ['IBM']
# --------
# IBM Network Control Programs
# ['IBM']
# --------
# IBM Notes
# ['IBM']
# --------
# IBM OMEGAMON
# ['IBM', 'OMEGAMON']
# --------
# IBM OS/2 (Software)
# ['IBM', 'OS']
# --------
# IBM OS/390
# ['IBM', 'OS']
# --------
# IBM OfficeVision
# ['IBM']
# --------
# IBM Omnifind
# ['IBM']
# --------
# IBM OpenDX
# ['IBM']
# --------
# IBM OpenPower
# ['IBM']
# --------
# IBM Optim
# ['IBM']
# --------
# IBM PC Networks
# ['IBM', 'PC']
# --------
# IBM PS/ValuePoint
# ['IBM', 'PS']
# --------
# IBM Parallel Sysplex
# ['IBM']
# --------
# IBM Personal Computer
# ['IBM']
# --------
# IBM Personal Computer XT
# ['IBM', 'XT']
# --------
# IBM Personal Computer/AT
# ['IBM', 'AT']
# --------
# IBM Personal Computing
# ['IBM']
# --------
# IBM Personal System/2
# ['IBM']
# --------
# IBM Planning Analytics Workspace
# ['IBM']
# --------
# IBM PureQuery
# ['IBM']
# --------
# IBM QRadar (SIEM Software)
# ['IBM']
# --------
# IBM Query Management Facility
# ['IBM']
# --------
# IBM RAD
# ['IBM', 'RAD']
# --------
# IBM RPG (Programming Language)
# ['IBM', 'RPG']
# --------
# IBM RSCT
# ['IBM', 'RSCT']
# --------
# IBM Rational Application Developer
# ['IBM']
# --------
# IBM Rational Asset Manager
# ['IBM']
# --------
# IBM Rational ClearCase
# ['IBM']
# --------
# IBM Rational Clearquest
# ['IBM']
# --------
# IBM Rational Functional Tester
# ['IBM']
# --------
# IBM Rational Method Composer
# ['IBM']
# --------
# IBM Rational Performance Tester
# ['IBM']
# --------
# IBM Rational SQABasic
# ['IBM']
# --------
# IBM Rational Software
# ['IBM']
# --------
# IBM Rational Software Architect
# ['IBM']
# --------
# IBM Rational Team Concert (Collaboration Tool)
# ['IBM']
# --------
# IBM Rational Unified Process
# ['IBM']
# --------
# IBM Resource Access Control Facility
# ['IBM']
# --------
# IBM SAN Volume Controllers
# ['IBM', 'SAN']
# --------
# IBM SQL/DS
# ['IBM', 'SQL', 'DS']
# --------
# IBM Sametime
# ['IBM']
# --------
# IBM Scalable Architecture For Financial Reporting
# ['IBM']
# --------
# IBM SecureWay Directory
# ['IBM']
# --------
# IBM Series/1
# ['IBM']
# --------
# IBM Service Management Framework
# ['IBM']
# --------
# IBM Services
# ['IBM']
# --------
# IBM Software
# ['IBM']
# --------
# IBM Software Configuration And Library Management (SCLM)
# ['IBM']
# --------
# IBM Spufi
# ['IBM']
# --------
# IBM Storage
# ['IBM']
# --------
# IBM System I
# ['IBM']
# --------
# IBM System Object Models
# ['IBM']
# --------
# IBM System P
# ['IBM']
# --------
# IBM System RS/6000
# ['IBM', 'RS']
# --------
# IBM System X
# ['IBM']
# --------
# IBM System Z
# ['IBM']
# --------
# IBM System Z Integrated Information Processor (ZIIP)
# ['IBM']
# --------
# IBM System Z10 (IBM System/360 Mainframe Line)
# ['IBM']
# --------
# IBM System Z9
# ['IBM']
# --------
# IBM System/3
# ['IBM']
# --------
# IBM System/34
# ['IBM']
# --------
# IBM System/36
# ['IBM']
# --------
# IBM System/360
# ['IBM']
# --------
# IBM System/370
# ['IBM']
# --------
# IBM System/38
# ['IBM']
# --------
# IBM Systems Application Architecture
# ['IBM']
# --------
# IBM Systems Director
# ['IBM']
# --------
# IBM Systems Network Architecture
# ['IBM']
# --------
# IBM TPNS
# ['IBM', 'TPNS']
# --------
# IBM Time Sharing Option
# ['IBM']
# --------
# IBM Tivoli Directory Servers
# ['IBM']
# --------
# IBM Tivoli Management Framework
# ['IBM']
# --------
# IBM Tivoli Storage Manager
# ['IBM']
# --------
# IBM Tivoli Workload Scheduler
# ['IBM']
# --------
# IBM TopView
# ['IBM']
# --------
# IBM TotalStorage Expert
# ['IBM']
# --------
# IBM Tririga
# ['IBM']
# --------
# IBM UniCA NetInsight
# ['IBM']
# --------
# IBM Utilities
# ['IBM']
# --------
# IBM VNET
# ['IBM', 'VNET']
# --------
# IBM ViaVoice
# ['IBM']
# --------
# IBM VisualAge
# ['IBM']
# --------
# IBM WAS
# ['IBM', 'WAS']
# --------
# IBM WebSphere Adapters
# ['IBM']
# --------
# IBM WebSphere DataPower SOA Appliances
# ['IBM', 'SOA']
# --------
# IBM WebSphere MQ
# ['IBM', 'MQ']
# --------
# IBM WebSphere Message Broker
# ['IBM']
# --------
# IBM WebSphere Portal
# ['IBM']
# --------
# IBM WebSphere Portlet Factory
# ['IBM']
# --------
# IBM WebSphere Process Server
# ['IBM']
# --------
# IBM WebSphere Software
# ['IBM']
# --------
# IBM Websphere Application Server
# ['IBM']
# --------
# IBM Websphere ESB
# ['IBM', 'ESB']
# --------
# IBM Websphere Edge Components
# ['IBM']
# --------
# IBM Websphere Host On-Demand
# ['IBM']
# --------
# IBM Websphere Integration Developer
# ['IBM']
# --------
# IBM Workload Manager For Z/OS (WLM/SRM)
# ['IBM', 'OS']
# --------
# IBM Workplace
# ['IBM']
# --------
# IBM XIV Storage Systems
# ['IBM', 'XIV']
# --------
# IBM XL C++
# ['IBM', 'XL']
# --------
# IBM Z/VM
# ['IBM', 'VM']
# --------
# IBM ZEnterprise Systems
# ['IBM']
# --------
# IC Programming
# ['IC']
# --------
# ICAM DEFinition For Function Modeling (IDEF0)
# ['ICAM']
# --------
# ICAM Definition (IDEF)
# ['ICAM']
# --------
# ICCP Certification
# ['ICCP']
# --------
# ICD Coding (ICD-9/ICD-10)
# ['ICD']
# --------
# ICE Validation
# ['ICE']
# --------
# ICH Guidelines
# ['ICH']
# --------
# ICL 2900 Series
# ['ICL']
# --------
# ICL VME
# ['ICL', 'VME']
# --------
# ICONIX Process
# ['ICONIX']
# --------
# IDA Pro
# ['IDA']
# --------
# IDS InfoLease (Asset Finance Technology)
# ['IDS']
# --------
# IDS Scheer
# ['IDS']
# --------
# IEC 60065
# ['IEC']
# --------
# IEC 60364
# ['IEC']
# --------
# IEC 60571
# ['IEC']
# --------
# IEC 60601
# ['IEC']
# --------
# IEC 60812
# ['IEC']
# --------
# IEC 61010
# ['IEC']
# --------
# IEC 61131
# ['IEC']
# --------
# IEC 61131 Standard
# ['IEC']
# --------
# IEC 61215
# ['IEC']
# --------
# IEC 61508
# ['IEC']
# --------
# IEC 61508 Standard
# ['IEC']
# --------
# IEC 61511
# ['IEC']
# --------
# IEC 61646
# ['IEC']
# --------
# IEC 61730
# ['IEC']
# --------
# IEC 61850
# ['IEC']
# --------
# IEC 61970 Standard
# ['IEC']
# --------
# IEC 62056
# ['IEC']
# --------
# IEC 62304
# ['IEC']
# --------
# IEC 62366
# ['IEC']
# --------
# IEC Standards
# ['IEC']
# --------
# IEEE 12207
# ['IEEE']
# --------
# IEEE 1284 Standard
# ['IEEE']
# --------
# IEEE 1451 (IEEE Standards)
# ['IEEE']
# --------
# IEEE 1584
# ['IEEE']
# --------
# IEEE 802
# ['IEEE']
# --------
# IEEE 802.10
# ['IEEE']
# --------
# IEEE 802.11
# ['IEEE']
# --------
# IEEE 802.11i-2004
# ['IEEE']
# --------
# IEEE 802.16
# ['IEEE']
# --------
# IEEE 802.1AE
# ['IEEE']
# --------
# IEEE 802.1D
# ['IEEE']
# --------
# IEEE 802.1Q
# ['IEEE']
# --------
# IEEE 802.1X
# ['IEEE']
# --------
# IEEE 802.1ad
# ['IEEE']
# --------
# IEEE 802.1ah-2008
# ['IEEE']
# --------
# IEEE 802.2
# ['IEEE']
# --------
# IEEE 802.20
# ['IEEE']
# --------
# IEEE 802.22
# ['IEEE']
# --------
# IEEE 802.3
# ['IEEE']
# --------
# IEEE 829
# ['IEEE']
# --------
# IEEE P1363
# ['IEEE']
# --------
# IEEE Standards Association
# ['IEEE']
# --------
# IEEE-488
# ['IEEE']
# --------
# IFS ERP
# ['IFS', 'ERP']
# --------
# IGMP Snooping
# ['IGMP']
# --------
# IGOR Pro
# ['IGOR']
# --------
# IIBA Agile Analysis Certification
# ['IIBA']
# --------
# IIS Debugging
# ['IIS']
# --------
# IIS Manager
# ['IIS']
# --------
# IIS Metabase
# ['IIS']
# --------
# IKVM.NET
# ['IKVM', 'NET']
# --------
# ILR Scale
# ['ILR']
# --------
# IMS Question And Test Interoperability Specification (QTI)
# ['IMS']
# --------
# IMSL Numerical Libraries
# ['IMSL']
# --------
# INI File
# ['INI']
# --------
# IOS Applications
# ['IOS']
# --------
# IOS Development
# ['IOS']
# --------
# IOS SDK
# ['IOS', 'SDK']
# --------
# IOSH Managing Safely
# ['IOSH']
# --------
# IOSH Working Safely
# ['IOSH']
# --------
# IP Access Controllers
# ['IP']
# --------
# IP Address Blocking
# ['IP']
# --------
# IP Address Management
# ['IP']
# --------
# IP Addressing
# ['IP']
# --------
# IP Cameras
# ['IP']
# --------
# IP Code
# ['IP']
# --------
# IP Connectivity Access Networks
# ['IP']
# --------
# IP Flow Information Export
# ['IP']
# --------
# IP Multicasting
# ['IP']
# --------
# IP Multimedia Subsystem
# ['IP']
# --------
# IP Pbx
# ['IP']
# --------
# IP Routing
# ['IP']
# --------
# IP Traceback
# ['IP']
# --------
# IP Tunnel
# ['IP']
# --------
# IRAP RMS Suite
# ['IRAP', 'RMS']
# --------
# IRCAM Signal Processing Workstation (ISPW)
# ['IRCAM']
# --------
# IRS Tax Forms
# ['IRS']
# --------
# IS-95
# ['IS']
# --------
# ISBN Management
# ['ISBN']
# --------
# ISCSI Boot Firmware Table
# ['ISCSI']
# --------
# ISDN Digital Subscriber Lines
# ['ISDN']
# --------
# ISIS/Draw
# ['ISIS']
# --------
# ISO 10006
# ['ISO']
# --------
# ISO 10012 Standard
# ['ISO']
# --------
# ISO 10993 Standard
# ['ISO']
# --------
# ISO 11783
# ['ISO']
# --------
# ISO 11898
# ['ISO']
# --------
# ISO 13485 Standard
# ['ISO']
# --------
# ISO 14000 Series
# ['ISO']
# --------
# ISO 14064
# ['ISO']
# --------
# ISO 14644
# ['ISO']
# --------
# ISO 14971 Standard
# ['ISO']
# --------
# ISO 15022
# ['ISO']
# --------
# ISO 15189 Standard
# ['ISO']
# --------
# ISO 15765-2
# ['ISO']
# --------
# ISO 19011 Standard
# ['ISO']
# --------
# ISO 20022
# ['ISO']
# --------
# ISO 22000 Standard
# ['ISO']
# --------
# ISO 25 Standard
# ['ISO']
# --------
# ISO 26262 Standard
# ['ISO']
# --------
# ISO 2709
# ['ISO']
# --------
# ISO 27799
# ['ISO']
# --------
# ISO 27799 Standard
# ['ISO']
# --------
# ISO 31000 Series
# ['ISO']
# --------
# ISO 50001 Standard
# ['ISO']
# --------
# ISO 7001
# ['ISO']
# --------
# ISO 8583 Standard
# ['ISO']
# --------
# ISO 9
# ['ISO']
# --------
# ISO 9000 Series
# ['ISO']
# --------
# ISO 9075
# ['ISO']
# --------
# ISO Recorder
# ['ISO']
# --------
# ISO/IEC 11179
# ['ISO', 'IEC']
# --------
# ISO/IEC 11801
# ['ISO', 'IEC']
# --------
# ISO/IEC 12207
# ['ISO', 'IEC']
# --------
# ISO/IEC 14882 (C++)
# ['ISO', 'IEC']
# --------
# ISO/IEC 15288
# ['ISO', 'IEC']
# --------
# ISO/IEC 15504
# ['ISO', 'IEC']
# --------
# ISO/IEC 15693
# ['ISO', 'IEC']
# --------
# ISO/IEC 17024
# ['ISO', 'IEC']
# --------
# ISO/IEC 17025
# ['ISO', 'IEC']
# --------
# ISO/IEC 20000
# ['ISO', 'IEC']
# --------
# ISO/IEC 2022 (Character Sets)
# ['ISO', 'IEC']
# --------
# ISO/IEC 27000
# ['ISO', 'IEC']
# --------
# ISO/IEC 27000-Series
# ['ISO', 'IEC']
# --------
# ISO/IEC 27001 Series
# ['ISO', 'IEC']
# --------
# ISO/IEC 27002
# ['ISO', 'IEC']
# --------
# ISO/IEC 38500
# ['ISO', 'IEC']
# --------
# ISO/IEC 7816
# ['ISO', 'IEC']
# --------
# ISO/IEC 9126
# ['ISO', 'IEC']
# --------
# ISO/IEEE 11073
# ['ISO', 'IEEE']
# --------
# ISO/PAS 28000
# ['ISO', 'PAS']
# --------
# ISO/TS 16949 Technical Specification
# ['ISO', 'TS']
# --------
# ISPI Certified
# ['ISPI']
# --------
# ISPM 15
# ['ISPM']
# --------
# ISS ECLSS
# ['ISS', 'ECLSS']
# --------
# IT Asset And Service Management
# ['IT']
# --------
# IT Asset Management
# ['IT']
# --------
# IT General Controls (ITGC)
# ['IT']
# --------
# IT Infrastructure
# ['IT']
# --------
# IT Portfolio Management
# ['IT']
# --------
# IT Risk Management
# ['IT']
# --------
# IT Sales
# ['IT']
# --------
# IT Security Architecture
# ['IT']
# --------
# IT Security Documentation
# ['IT']
# --------
# IT Service Management
# ['IT']
# --------
# IT Service Management Forum
# ['IT']
# --------
# ITIL Certifications
# ['ITIL']
# --------
# ITIL Expert Certification
# ['ITIL']
# --------
# ITIL Foundation Certification
# ['ITIL']
# --------
# ITIL Practitioner Certification
# ['ITIL']
# --------
# ITIL Security Management
# ['ITIL']
# --------
# ITRON Project
# ['ITRON']
# --------
# ITU-T
# ['ITU']
# --------
# IV (Intravenous) Certification
# ['IV']
# --------
# IV Semiconductor
# ['IV']
# --------
# IVRU - Interactive Voice Response Unit
# ['IVRU']
# --------
# IVX Index
# ['IVX']
# --------
# IWARP Protocol
# ['IWARP']
# --------
# Image Mastering API
# ['API']
# --------
# Infocad CAFM Systems
# ['CAFM']
# --------
# Insight ERP
# ['ERP']
# --------
# Installer VISE
# ['VISE']
# --------
# Integer BASIC
# ['BASIC']
# --------
# Intel HEX
# ['HEX']
# --------
# IntelliJ IDEA
# ['IDEA']
# --------
# Internet OS
# ['OS']
# --------
# Intracellular PH
# ['PH']
# --------
# JAWS Scripting Language
# ['JAWS']
# --------
# JAX-WS
# ['JAX', 'WS']
# --------
# JBASE ODBC Connector
# ['JBASE', 'ODBC']
# --------
# JBoss EAP
# ['EAP']
# --------
# JBoss Enterprise SOA Platforms
# ['SOA']
# --------
# JCAHO Standards
# ['JCAHO']
# --------
# JCL Certification
# ['JCL']
# --------
# JD Edwards EnterpriseOne
# ['JD']
# --------
# JDBC Driver
# ['JDBC']
# --------
# JIRA Studio
# ['JIRA']
# --------
# JOSSO - Java Open Single Sign-On
# ['JOSSO']
# --------
# JPEG 2000
# ['JPEG']
# --------
# JPOS Framework
# ['JPOS']
# --------
# JQuery UI
# ['UI']
# --------
# ...
# SAP Business Suite
# ['SAP']
# --------
# SAP BusinessObjects
# ['SAP']
# --------
# SAP CO
# ['SAP', 'CO']
# --------
# SAP CRM
# ['SAP', 'CRM']
# --------
# SAP CS
# ['SAP', 'CS']
# --------
# SAP Composite Application Frameworks
# ['SAP']
# --------
# SAP Concur (Travel And Invoice Software)
# ['SAP']
# --------
# SAP Configuration
# ['SAP']
# --------
# SAP Connector
# ['SAP']
# --------
# SAP Contract Lifecycle Management
# ['SAP']
# --------
# SAP DMS
# ['SAP', 'DMS']
# --------
# SAP EBP
# ['SAP', 'EBP']
# --------
# SAP EC
# ['SAP', 'EC']
# --------
# SAP EP
# ['SAP', 'EP']
# --------
# SAP ERP
# ['SAP', 'ERP']
# --------
# SAP EWM
# ['SAP', 'EWM']
# --------
# SAP FI
# ['SAP', 'FI']
# --------
# SAP FI/CO
# ['SAP', 'FI', 'CO']
# --------
# SAP Fieldglass (Vendor Management Tool)
# ['SAP']
# --------
# SAP Financial Management
# ['SAP']
# --------
# SAP Financial Services
# ['SAP']
# --------
# SAP Fiori
# ['SAP']
# --------
# SAP Frontend
# ['SAP']
# --------
# SAP Functional
# ['SAP']
# --------
# SAP GUIing
# ['SAP']
# --------
# SAP HANA
# ['SAP', 'HANA']
# --------
# SAP Human Resource Management Software
# ['SAP']
# --------
# SAP IDES
# ['SAP', 'IDES']
# --------
# SAP IS-U
# ['SAP', 'IS']
# --------
# SAP Implementation
# ['SAP']
# --------
# SAP Infrastructure
# ['SAP']
# --------
# SAP Inventory Management Software
# ['SAP']
# --------
# SAP IoT
# ['SAP']
# --------
# SAP Java Connector
# ['SAP']
# --------
# SAP Knowledge Management
# ['SAP']
# --------
# SAP Knowledge Warehouse
# ['SAP']
# --------
# SAP Logistics
# ['SAP']
# --------
# SAP Logistics Execution System
# ['SAP']
# --------
# SAP Logistics Information System
# ['SAP']
# --------
# SAP Lumira
# ['SAP']
# --------
# SAP Manufacturing Execution (ME)
# ['SAP']
# --------
# SAP Material Management
# ['SAP']
# --------
# SAP NetWeaver
# ['SAP']
# --------
# SAP NetWeaver Application Servers
# ['SAP']
# --------
# SAP NetWeaver Business Warehouse
# ['SAP']
# --------
# SAP NetWeaver Data Management
# ['SAP']
# --------
# SAP NetWeaver Development Infrastructure
# ['SAP']
# --------
# SAP NetWeaver Portals
# ['SAP']
# --------
# SAP NetWeaver Process Integration
# ['SAP']
# --------
# SAP NetWeaver Visual Composer
# ['SAP']
# --------
# SAP Office
# ['SAP']
# --------
# SAP Plant Maintenance
# ['SAP']
# --------
# SAP Point Of Sale
# ['SAP']
# --------
# SAP Product Lifecycle Management (PLM)
# ['SAP']
# --------
# SAP Production Planning
# ['SAP']
# --------
# SAP Project Management
# ['SAP']
# --------
# SAP Project System
# ['SAP']
# --------
# SAP Quality ManageMent
# ['SAP']
# --------
# SAP R/3
# ['SAP']
# --------
# SAP Recipe Management
# ['SAP']
# --------
# SAP Resource And Portfolio Management
# ['SAP']
# --------
# SAP Sales And Distribution
# ['SAP']
# --------
# SAP Security
# ['SAP']
# --------
# SAP Service Management
# ['SAP']
# --------
# SAP Solution Manager
# ['SAP']
# --------
# SAP SuccessFactors
# ['SAP']
# --------
# SAP Supplier Relationship Management (SAP SRM)
# ['SAP']
# --------
# SAP Supply Chain Management (SCM)
# ['SAP']
# --------
# SAP Sybase Adaptive Server Enterprise
# ['SAP']
# --------
# SAP Sybase SQL
# ['SAP', 'SQL']
# --------
# SAP Sybase SQL Anywhere
# ['SAP', 'SQL']
# --------
# SAP Technology Consulting
# ['SAP']
# --------
# SAP Transport Management Systems
# ['SAP']
# --------
# SAP Treasury And Risk Management
# ['SAP']
# --------
# SAP Tutor
# ['SAP']
# --------
# SAP V3.X
# ['SAP']
# --------
# SAP V4.X
# ['SAP']
# --------
# SAP Warehouse Management
# ['SAP']
# --------
# SAP XAPP
# ['SAP', 'XAPP']
# --------
# SAP XMII (SAP NetWeaver)
# ['SAP', 'XMII']
# --------
# SARS Software Products
# ['SARS']
# --------
# SARTECH Examinations
# ['SARTECH']
# --------
# SAS Appdev Studio
# ['SAS']
# --------
# SAS Certified Advanced Programmer
# ['SAS']
# --------
# SAS Forecast Servers
# ['SAS']
# --------
# SAS Integration Technologies
# ['SAS']
# --------
# SAS Learning Edition
# ['SAS']
# --------
# SAS Macros
# ['SAS']
# --------
# SAS Management Console
# ['SAS']
# --------
# SAS Metadata Servers
# ['SAS']
# --------
# SAS OLAP Servers
# ['SAS', 'OLAP']
# --------
# SAS Scalable Performance Data Servers
# ['SAS']
# --------
# SAS Statistical Analysis
# ['SAS']
# --------
# SAS Text Miner
# ['SAS']
# --------
# SAS Web OLAP Viewer
# ['SAS', 'OLAP']
# --------
# SAS Web Report Studio
# ['SAS']
# --------
# SAS/Base
# ['SAS']
# --------
# SAS/IML
# ['SAS', 'IML']
# --------
# SAS/STAT
# ['SAS', 'STAT']
# --------
# SCARA Robot
# ['SCARA']
# --------
# SCIM- System For Cross-Domain Identity Management
# ['SCIM']
# --------
# SCO OpenServers
# ['SCO']
# --------
# SD Cards
# ['SD']
# --------
# SDL MultiTerm
# ['SDL']
# --------
# SDL Trados
# ['SDL']
# --------
# SEC Filing
# ['SEC']
# --------
# SEO Copywriting
# ['SEO']
# --------
# SES Americom
# ['SES']
# --------
# SET Language (SETL)
# ['SET']
# --------
# SEasonal SOIL (SESOIL)
# ['SOIL']
# --------
# SHA-256
# ['SHA']
# --------
# SHA-512
# ['SHA']
# --------
# SHRM-CP (Society for Human Resource Management Certified Professional)
# ['SHRM', 'CP']
# --------
# SHRM-SCP (Society for Human Resource Management Senior Certified Professional)
# ['SHRM', 'SCP']
# --------
# SIM Application Toolkit
# ['SIM']
# --------
# SIM Lock
# ['SIM']
# --------
# SIMATIC WinCC (SCADA System)
# ['SIMATIC']
# --------
# SIPOC Process
# ['SIPOC']
# --------
# SLAM Algorithms (Simultaneous Localization And Mapping)
# ['SLAM']
# --------
# SMART Criteria
# ['SMART']
# --------
# SMART Sympodium
# ['SMART']
# --------
# SME Finance
# ['SME']
# --------
# SME Servers
# ['SME']
# --------
# SMPTE 292M Standard
# ['SMPTE']
# --------
# SMS Banking
# ['SMS']
# --------
# SMS Gateway
# ['SMS']
# --------
# SMS Hubbing
# ['SMS']
# --------
# SMT Placement Equipment
# ['SMT']
# --------
# SNIA Certified Architecture
# ['SNIA']
# --------
# SNIA Certified Professional
# ['SNIA']
# --------
# SNIA Certified Systems Engineer
# ['SNIA']
# --------
# SNL Financial
# ['SNL']
# --------
# SNMP Simulator
# ['SNMP']
# --------
# SNMP Trap Handler (SNMPTT)
# ['SNMP']
# --------
# SNP Array
# ['SNP']
# --------
# SNP Genotyping
# ['SNP']
# --------
# SOAP With Attachments
# ['SOAP']
# --------
# SOASTA CloudTest
# ['SOASTA']
# --------
# SOCET SET
# ['SOCET', 'SET']
# --------
# SOFiSTiK AG
# ['AG']
# --------
# SORA Training
# ['SORA']
# --------
# SOS Online Backup
# ['SOS']
# --------
# SPARQL Protocol And RDF Query Language (SPARQL)
# ['SPARQL', 'RDF']
# --------
# SPC XL
# ['SPC', 'XL']
# --------
# SPITBOL Compiler
# ['SPITBOL']
# --------
# SPSS Modeler
# ['SPSS']
# --------
# SQF (Safe Quality Food) Practitioner
# ['SQF']
# --------
# SQL And Java (SQLJ)
# ['SQL']
# --------
# SQL Anywhere
# ['SQL']
# --------
# SQL Azure
# ['SQL']
# --------
# SQL Common Language Runtime (SQL CLR)
# ['SQL']
# --------
# SQL Injection
# ['SQL']
# --------
# SQL Plan Management
# ['SQL']
# --------
# SQL Server 2005 DBa Certified Professional
# ['SQL']
# --------
# SQL Server Agent
# ['SQL']
# --------
# SQL Server Analysis Services
# ['SQL']
# --------
# SQL Server Compact
# ['SQL']
# --------
# SQL Server Express
# ['SQL']
# --------
# SQL Server Integration Services (SSIS)
# ['SQL']
# --------
# SQL Server Management Objects
# ['SQL']
# --------
# SQL Server Management Studio
# ['SQL']
# --------
# SQL Server Master Data Services
# ['SQL']
# --------
# SQL Server Notification Services
# ['SQL']
# --------
# SQL Server Reporting Services
# ['SQL']
# --------
# SQL Services
# ['SQL']
# --------
# SQL Tuning
# ['SQL']
# --------
# SQL-2003
# ['SQL']
# --------
# SQL/Persistent Stored Modules (SQL/PSM)
# ['SQL']
# --------
# SQuirreL SQL Client
# ['SQL']
# --------
# SSAS 2012
# ['SSAS']
# --------
# SSH Filesystem (SSHFS)
# ['SSH']
# --------
# SSL Acceleration
# ['SSL']
# --------
# SSL Security
# ['SSL']
# --------
# STD 8
# ['STD']
# --------
# STD Bus
# ['STD']
# --------
# SU-8 Photoresist
# ['SU']
# --------
# SUSE Linux
# ['SUSE']
# --------
# SUSE Linux Distributions
# ['SUSE']
# --------
# SUSE Linux Enterprise Desktops
# ['SUSE']
# --------
# SUSE Linux Enterprise Servers
# ['SUSE']
# --------
# SWOT Analysis
# ['SWOT']
# --------
# SXAL/MBAL
# ['SXAL', 'MBAL']
# --------
# SYS/BIOS
# ['SYS', 'BIOS']
# --------
# Sage ERP
# ['ERP']
# --------
# Sage ERP Accpac
# ['ERP']
# --------
# Sage SAFE X3
# ['SAFE']
# --------
# Salesforce CPQ Specialist
# ['CPQ']
# --------
# Scholastic READ 180
# ['READ']
# --------
# Secure FTP (Software)
# ['FTP']
# --------
# Semantic HTML
# ['HTML']
# --------
# Serial Attached SCSI
# ['SCSI']
# --------
# Serial FPDP
# ['FPDP']
# --------
# Siebel CRM
# ['CRM']
# --------
# Siebel EAI
# ['EAI']
# --------
# Siebel EIM
# ['EIM']
# --------
# Siebel ERM
# ['ERM']
# --------
# Siebel VB
# ['VB']
# --------
# Siemens NX
# ['NX']
# --------
# Simatic S5 PLC
# ['PLC']
# --------
# Simple API For XML
# ['API', 'XML']
# --------
# Simple And Protected GSSAPI Negotiation Mechanism (SPNEGO)
# ['GSSAPI']
# --------
# Simple DNS Plus
# ['DNS']
# --------
# Single UNIX Specification
# ['UNIX']
# --------
# SliTaz GNU/Linux
# ['GNU']
# --------
# Small Interfering RNA
# ['RNA']
# --------
# Social CRM
# ['CRM']
# --------
# Source SDK
# ['SDK']
# --------
# Spring AOP
# ['AOP']
# --------
# Spring MVC
# ['MVC']
# --------
# Standard SQL
# ['SQL']
# --------
# State Chart XML (SCXML)
# ['XML']
# --------
# Static HTML
# ['HTML']
# --------
# Stratus VOS
# ['VOS']
# --------
# Structured BASIC (SBASIC)
# ['BASIC']
# --------
# Structured MUMPS (SMUMPS)
# ['MUMPS']
# --------
# Successive Approximation ADC
# ['ADC']
# --------
# Sun ONE
# ['ONE']
# --------
# Surround SCM
# ['SCM']
# --------
# Swagger UI
# ['UI']
# --------
# Sybase IQ
# ['IQ']
# --------
# Sybase RAP
# ['RAP']
# --------
# Synapse EHR (Medical)
# ['EHR']
# --------
# System Management BIOS
# ['BIOS']
# --------
# TA Cloning
# ['TA']
# --------
# TARGET 3001!
# ['TARGET']
# --------
# TC Shell (Unix)
# ['TC']
# --------
# TCP Acceleration
# ['TCP']
# --------
# TCP Congestion-Avoidance Algorithm
# ['TCP']
# --------
# TCP Offload Engine
# ['TCP']
# --------
# TCP Tuning
# ['TCP']
# --------
# TCP Wrapper
# ['TCP']
# --------
# TCP/IP
# ['TCP', 'IP']
# --------
# TCP/IP Administration
# ['TCP', 'IP']
# --------
# TCP/IP Models
# ['TCP', 'IP']
# --------
# TD-SCDMA
# ['TD', 'SCDMA']
# --------
# TDS Telecom
# ['TDS']
# --------
# TEEX Certified Safety And Health Official
# ['TEEX']
# --------
# TI InterActive!
# ['TI']
# --------
# TI MSP430
# ['TI']
# --------
# TIA/EIA-568
# ['TIA', 'EIA']
# --------
# TIA/EIA-569
# ['TIA', 'EIA']
# --------
# TIA/EIA-570
# ['TIA', 'EIA']
# --------
# TIBCO ActiveMatrix
# ['TIBCO']
# --------
# TIBCO Activeenterprise
# ['TIBCO']
# --------
# TIBCO Business Studio
# ['TIBCO']
# --------
# TIBCO Businessworks
# ['TIBCO']
# --------
# TIBCO Dataexchange
# ['TIBCO']
# --------
# TIBCO Designer
# ['TIBCO']
# --------
# TIBCO EMS
# ['TIBCO', 'EMS']
# --------
# TIBCO Hawk
# ['TIBCO']
# --------
# TIBCO Rendezvous
# ['TIBCO']
# --------
# TIBCO iProcess Engine
# ['TIBCO']
# --------
# TL 9000 Standard
# ['TL']
# --------
# TMP Directional Marketing
# ['TMP']
# --------
# TMW Systems
# ['TMW']
# --------
# TN Status
# ['TN']
# --------
# TOPO Cloning
# ['TOPO']
# --------
# TPL Tables
# ['TPL']
# --------
# TR-069
# ['TR']
# --------
# TRADACOMS Standard
# ['TRADACOMS']
# --------
# TRON Project
# ['TRON']
# --------
# TRS-80
# ['TRS']
# --------
# TSIS-CORSIM (Software)
# ['TSIS', 'CORSIM']
# --------
# TUNEL Assay
# ['TUNEL']
# --------
# Tally ERP
# ['ERP']
# --------
# Technology CAD (Electronic Design Automation)
# ['CAD']
# --------
# Teradata Certified SQL Specialist
# ['SQL']
# --------
# Teradata SQL
# ['SQL']
# --------
# Text Over IP
# ['IP']
# --------
# Three-CCD Camera
# ['CCD']
# --------
# Tiki Wiki CMS Groupware
# ['CMS']
# --------
# Titan CMS
# ['CMS']
# --------
# Title 47 CFR Part 15
# ['CFR']
# --------
# Transact-SQL
# ['SQL']
# --------
# Transparent LAN Services (Ethernet)
# ['LAN']
# --------
# Triple DES
# ['DES']
# --------
# True BASIC
# ['BASIC']
# --------
# Tweak UI
# ['UI']
# --------
# U-SQL
# ['SQL']
# --------
# UCSC Genome Browser
# ['UCSC']
# --------
# UCSD Pascal
# ['UCSD']
# --------
# UCSF Chimera
# ['UCSF']
# --------
# UL 94 Standard
# ['UL']
# --------
# UM Interface
# ['UM']
# --------
# UML Tool
# ['UML']
# --------
# UMTS Frequency Bands
# ['UMTS']
# --------
# UMTS Terrestrial Radio Access Networks
# ['UMTS']
# --------
# UNIVAC 1100/2200 Series
# ['UNIVAC']
# --------
# UNIVAC EXEC
# ['UNIVAC', 'EXEC']
# --------
# URL Redirection
# ['URL']
# --------
# USB Flash Drives
# ['USB']
# --------
# USB Mass Storage Device Class
# ['USB']
# --------
# USDF Certified Instructor
# ['USDF']
# --------
# UX Research
# ['UX']
# --------
# UX Writing
# ['UX']
# --------
# Ubuntu GNOME
# ['GNOME']
# --------
# Ultimate Boot CD For Windows
# ['CD']
# --------
# Ultra-Mobile PC
# ['PC']
# --------
# Umbrello UML Modeller
# ['UML']
# --------
# Unified Profile For DoDAF/MODAF (UPDM)
# ['MODAF']
# --------
# Unisys DMSII
# ['DMSII']
# --------
# Unisys MCP Programming Languages
# ['MCP']
# --------
# Unix System III
# ['III']
# --------
# VA Loans
# ['VA']
# --------
# VA SAR/LAPP Designation
# ['VA', 'SAR', 'LAPP']
# --------
# VAX 6000
# ['VAX']
# --------
# VAX 7000/10000
# ['VAX']
# --------
# VAX 9000
# ['VAX']
# --------
# VAX Macro
# ['VAX']
# --------
# VDA 6.1 Standard
# ['VDA']
# --------
# VESA BIOS Extensions
# ['VESA', 'BIOS']
# --------
# VGA Connectors
# ['VGA']
# --------
# VHF Radios
# ['VHF']
# --------
# VHSIC Hardware Description Language (VHDL)
# ['VHSIC']
# --------
# VIN Etching
# ['VIN']
# --------
# VLAN Access Controls
# ['VLAN']
# --------
# VLAN Hopping
# ['VLAN']
# --------
# VLAN Management Policy Server
# ['VLAN']
# --------
# VLAN Trunking Protocol (VTP)
# ['VLAN']
# --------
# VLC Media Player
# ['VLC']
# --------
# VME EXtensions For Instrumentation
# ['VME']
# --------
# VMWare Workspace ONE
# ['ONE']
# --------
# VMware ESX Servers
# ['ESX']
# --------
# VMware VMFS
# ['VMFS']
# --------
# VOR/DME
# ['VOR', 'DME']
# --------
# VP/MS
# ['VP', 'MS']
# --------
# VPN Clients
# ['VPN']
# --------
# VPN Tunnels
# ['VPN']
# --------
# VS/9
# ['VS']
# --------
# VU Meter
# ['VU']
# --------
# Vector NTI
# ['NTI']
# --------
# Verax NMS
# ['NMS']
# --------
# Video Acceleration API
# ['API']
# --------
# Video BIOS
# ['BIOS']
# --------
# Virtual IP Address
# ['IP']
# --------
# Virtual POS
# ['POS']
# --------
# Virtual Private LAN Services
# ['LAN']
# --------
# Visual Basic .NET (Programming Language)
# ['NET']
# --------
# Visual MODFLOW
# ['MODFLOW']
# --------
# Visual Paradigm For UML
# ['UML']
# --------
# Voice Over IP
# ['IP']
# --------
# Voice Over WLAN
# ['WLAN']
# --------
# Vosao CMS
# ['CMS']
# --------
# Vtiger CRM
# ['CRM']
# --------
# Vulkan Graphics API
# ['API']
# --------
# W-CDMA (UMTS)
# ['CDMA']
# --------
# WAN Interface Card
# ['WAN']
# --------
# WAN Optimization
# ['WAN']
# --------
# WAN Technologies
# ['WAN']
# --------
# WATerloo FORTRAN IV (WATFIV)
# ['FORTRAN', 'IV']
# --------
# WFX Wrestling
# ['WFX']
# --------
# WHO Adverse Reactions Terminology (WHOART)
# ['WHO']
# --------
# WHQL Testing
# ['WHQL']
# --------
# WOW Certified Web Designer Apprentice
# ['WOW']
# --------
# WPF Controls
# ['WPF']
# --------
# WS-Security
# ['WS']
# --------
# Wake-On-LAN
# ['LAN']
# --------
# Web SQL Databases
# ['SQL']
# --------
# Web UI
# ['UI']
# --------
# WebStudy Learning LMS
# ['LMS']
# --------
# Wilderness EMT
# ['EMT']
# --------
# Window CLI
# ['CLI']
# --------
# Windows API
# ['API']
# --------
# Windows Audio Session API (WASAPI)
# ['API']
# --------
# Windows DVD Maker
# ['DVD']
# --------
# Windows Embedded CE 6.0
# ['CE']
# --------
# Windows Installer XML (WIX)
# ['XML']
# --------
# Windows Live ID
# ['ID']
# --------
# Windows RT
# ['RT']
# --------
# Windows USER
# ['USER']
# --------
# Windows Virtual PC
# ['PC']
# --------
# Windows Workflow Foundation In .NET 4
# ['NET']
# --------
# Wing IDE
# ['IDE']
# --------
# Wireless LAN
# ['LAN']
# --------
# Wireless LAN Controllers
# ['LAN']
# --------
# Wireless USB
# ['USB']
# --------
# Wireless WAN
# ['WAN']
# --------
# Word VBA
# ['VBA']
# --------
# Workbooks CRM
# ['CRM']
# --------
# X.25 Over TCP (XOT)
# ['TCP']
# --------
# XAML Browser Applications
# ['XAML']
# --------
# XAUI Standard
# ['XAUI']
# --------
# XFP Transceiver
# ['XFP']
# --------
# XHTML Mobile Profiles
# ['XHTML']
# --------
# XML Certification Programs
# ['XML']
# --------
# XML Concepts
# ['XML']
# --------
# XML Configuration Access Protocols
# ['XML']
# --------
# XML Data Binding
# ['XML']
# --------
# XML Data Package
# ['XML']
# --------
# XML Databases
# ['XML']
# --------
# XML Editor
# ['XML']
# --------
# XML Encryption
# ['XML']
# --------
# XML Firewall
# ['XML']
# --------
# XML For Analysis
# ['XML']
# --------
# XML Information Set
# ['XML']
# --------
# XML Interface For Network Services
# ['XML']
# --------
# XML Libraries
# ['XML']
# --------
# XML Literals
# ['XML']
# --------
# XML Localisation Interchange File Format (XLIFF)
# ['XML']
# --------
# XML Markup Languages
# ['XML']
# --------
# XML Master Basic
# ['XML']
# --------
# XML Master Certification
# ['XML']
# --------
# XML Metadata Interchange
# ['XML']
# --------
# XML Notepad
# ['XML']
# --------
# XML Pipeline
# ['XML']
# --------
# XML Representations Of Lexicons
# ['XML']
# --------
# XML Resource Library
# ['XML']
# --------
# XML Schema
# ['XML']
# --------
# XML Schema Editor
# ['XML']
# --------
# XML Script
# ['XML']
# --------
# XML Signatures
# ['XML']
# --------
# XML Transformation Languages (XML-Based Standards)
# ['XML']
# --------
# XML Transition Network Definition (XTND)
# ['XML']
# --------
# XML Validation
# ['XML']
# --------
# XML-Based Programming Languages
# ['XML']
# --------
# XML-RPC
# ['XML', 'RPC']
# --------
# XMODEM Protocol
# ['XMODEM']
# --------
# XPC Target (Simulation Programming Language)
# ['XPC']
# --------
# XSL Formatting Objects
# ['XSL']
# --------
# XTX Standard
# ['XTX']
# --------
# Xilinx ISE
# ['ISE']
# --------
# YIG Sphere
# ['YIG']
# --------
# YUI Libraries
# ['YUI']
# --------
# Yii PHP Framework
# ['PHP']
# --------
# YouTube API
# ['API']
# --------
# ZMODEM Protocol
# ['ZMODEM']
# --------
# Zend PHP Certification
# ['PHP']
# --------
# Zilog SCC (I/O Chips)
# ['SCC']
# --------
# z/OS
# ['OS']
# --------

# %%
import collections
dist = collections.Counter(subs)

# %%
for key in skills_db :
    if skills_db[key]['skill_len']>2:
        
        skill_name = skills_db[key]['skill_name']
        new_skill_name  = remove_btwn_par(skill_name)
        skill_low = skills_db[key]['low_surface_forms']
        sub_abv = extract_sub_forms(new_skill_name)
        for abv in  sub_abv : 
            if dist[abv]==1:
                skill_low.append(abv)
        skills_db[key]['low_surface_forms'] =  skill_low

# %%
a =[skills_db[key] for key in skills_db if skills_db[key]['skill_len']>2 and len(skills_db[key]['low_surface_forms'])>0 ]
len(a)
# Out:
# 274

# %%
# save
with open('../skillNer/data/skill_db_relax_20.json', 'w', encoding='utf-8') as f:
    json.dump(skills_db, f, ensure_ascii=False, indent=4)

# %%
# Out:
# 2
