# %%
# change working directory to root directory
import os

os.chdir("../")
os.getcwd()
# Out:
# '/Users/mac/Desktop/msda_labour_graph/MSDA jobs graph '

# %%
import pandas as pd

# %%
from skillNer.text_class import Text

example_text = "Apple is looking at buying U.K. startup for $1 billion, Yehh" + \
        "Hey, Geeks !, How are you?, you have a good mastery of English language" + \
        "as team spirit they have a good mastery of English"

# build text object
text = Text(example_text)

# %%
# %%timeit
text = Text(example_text)
# Out:
# 225 ms ± 47.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# summary
arr = [
    [text[i], text[i].is_stop_word, text[i].is_matchable, text[i].stemmed, text[i].lemmed]
for i in range(len(text))]

df = pd.DataFrame(arr, columns=["raw word", "is stop word", "is matchable", "stemmed ", "lemmed"])

df
# Out:
#       raw word  is stop word  is matchable   stemmed      lemmed
# 0        apple         False          True       appl      apple
# 1           is          True          True         is         be
# 2      looking         False          True       look       look
# 3           at          True          True         at         at
# 4       buying         False          True        buy        buy
# 5           uk         False          True         uk         uk
# 6      startup         False          True    startup    startup
# 7          for          True          True        for        for
# 8            1         False          True          1          1
# 9      billion         False          True    billion    billion
# 10     yehhhey         False          True    yehhhey    yehhhey
# 11       geeks         False          True       geek       geek
# 12         how          True          True        how        how
# 13         are          True          True        are         be
# 14         you          True          True        you        you
# 15         you          True         False        you        you
# 16        have          True         False       have       have
# 17           a          True          True          a          a
# 18        good         False         False       good       good
# 19     mastery         False         False    masteri    mastery
# 20          of          True         False         of         of
# 21     english         False          True    english    english
# 22  languageas         False          True  languagea  languagea
# 23        team         False         False       team       team
# 24      spirit         False         False     spirit     spirit
# 25        they          True          True       they       they
# 26        have          True          True       have       have
# 27           a          True          True          a          a
# 28        good         False          True       good       good
# 29     mastery         False          True    masteri    mastery
# 30          of          True          True         of         of
# 31     english         False          True    english    english

# %%
# print raw text, stem, lem
print(text)
print("********")
print("********")
print(text.stemmed())
print("********")
print("********")
print(text.lemmed())
# Out:
# Apple is looking at buying U.K. startup for $1 billion, YehhHey, Geeks !, How are you?, you have a good mastery of English languageas team spirit they have a good mastery of English
# ********
# ********
# appl is look at buy uk startup for 1 billion yehhhey geek how are you you have a good masteri of english languagea team spirit they have a good masteri of english
# ********
# ********
# apple be look at buy uk startup for 1 billion yehhhey geek how be you you have a good mastery of english languagea team spirit they have a good mastery of english

# %%
Text("Badr MOUFAD is good emplyee")
