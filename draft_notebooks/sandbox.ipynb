# %%
import os
os.chdir("../")
  
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\skillNer-repo\\SkillNER'

# %%
import en_core_web_lg
import spacy
from spacy.matcher import PhraseMatcher
from nltk.corpus import stopwords

# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
from skillNer.general_params import SKILL_DB


# init params of skill extractor
nlp = en_core_web_lg.load()
stop_words = set(stopwords.words('english'))

# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher, stop_words)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
#%%timeit
# extract skills from job_description
job_description = """
You are a Python Developer with a solid experience in Web development and  esx
and have a thoughtful expatriation and manage project . You're passionate and powerful.
You are recognized for your ability to evolve within a team and around common projects
and you easily adapt in a new environment. javascript and node and french and english
"""


annotations = skill_extractor.annotate(job_description )

#pprint.pprint(annotations['logs'])

# %%
# usual display
skill_extractor.display(annotations)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">you are a
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Python (Programming Language)</span>
# </mark>
#  developer with a solid experience in
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Web Development</span>
# </mark>
#  and
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     esx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VMware ESX Servers</span>
# </mark>
#  and have a thoughtful expatriation and
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manage project
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Project Management</span>
# </mark>
#  you re passionate and powerful you are recognized for your ability to evolve within a team and around common projects and you easily
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adapt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Adaptability</span>
# </mark>
#  in a new environment
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     javascript
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JavaScript (Programming Language)</span>
# </mark>
#  and
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     node
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Node.js</span>
# </mark>
#  and
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     french
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">French Language</span>
# </mark>
#  and
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     english
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">English Language</span>
# </mark>
# </div></span>

# %%
# details of annotations
skill_extractor.display_details(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspyou are a&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_755()'onmouseenter='mouseEnterHandler_KS125LS6N7WP4S6SFTCK_755()'>
#             python
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS125LS6N7WP4S6SFTCK_755'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Python (Programming Language)
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS125LS6N7WP4S6SFTCK_755() {
#             document.getElementById("KS125LS6N7WP4S6SFTCK_755").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_755() {
#             document.getElementById("KS125LS6N7WP4S6SFTCK_755").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspdeveloper with a solid experience in&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS122Z36QK3N5097B5JH_614()'onmouseenter='mouseEnterHandler_KS122Z36QK3N5097B5JH_614()'>
#             web development
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS122Z36QK3N5097B5JH_614'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Web Development
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             full_matches
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS122Z36QK3N5097B5JH_614() {
#             document.getElementById("KS122Z36QK3N5097B5JH_614").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS122Z36QK3N5097B5JH_614() {
#             document.getElementById("KS122Z36QK3N5097B5JH_614").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspand&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS123NQ6N6KV4RM7RTXJ_716()'onmouseenter='mouseEnterHandler_KS123NQ6N6KV4RM7RTXJ_716()'>
#             esx
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS123NQ6N6KV4RM7RTXJ_716'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             VMware ESX Servers
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS123NQ6N6KV4RM7RTXJ_716() {
#             document.getElementById("KS123NQ6N6KV4RM7RTXJ_716").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS123NQ6N6KV4RM7RTXJ_716() {
#             document.getElementById("KS123NQ6N6KV4RM7RTXJ_716").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspand have a thoughtful expatriation and&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS1267F6MSPN366LX7ST_774()'onmouseenter='mouseEnterHandler_KS1267F6MSPN366LX7ST_774()'>
#             manage project
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS1267F6MSPN366LX7ST_774'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Project Management
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             2
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS1267F6MSPN366LX7ST_774() {
#             document.getElementById("KS1267F6MSPN366LX7ST_774").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS1267F6MSPN366LX7ST_774() {
#             document.getElementById("KS1267F6MSPN366LX7ST_774").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspyou re passionate and powerful you are recognized for your ability to evolve within a team and around common projects and you easily&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_KS120626HMWCXJWJC7VK_466()'onmouseenter='mouseEnterHandler_KS120626HMWCXJWJC7VK_466()'>
#             adapt
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS120626HMWCXJWJC7VK_466'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Adaptability
#         </span>
