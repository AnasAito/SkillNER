# %%
import os
os.chdir("../")
  
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\skillNer-repo\\SkillNER'

# %%
from skillNer.visualizer.html_elements import render_phrase
from skillNer.visualizer.phrase_class import Phrase
from IPython.core.display import HTML

phrase = Phrase(text="an extracted skill")

phrase.is_skill = True
phrase.skill_id = "ksdfkujsd46546"
phrase.skill_type = "Hard skill"
phrase.type_matching = "full_match"
phrase.skill_name = "real name"
phrase.score = 0.99

def document(children):
    content = f"""
        <head>
            <link
                id="external-css"
                rel="stylesheet"
                type="text/css"
                href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
                media="all"
            />
        </head>

        <body>
            <div id="root" class="flex inline mb-48">
                {" ".join(children)}
            </div>
        </body>
    """
    return HTML(content)

# print(render_phrase(phrase))

document(children=[render_phrase(phrase)])
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="flex inline mb-48">
#
#         <span class='relative' >
#
#         <div class='flex items border p-2 px-6 pb-6 rounded-lg mx-2 cursor-pointer' onmouseleave='mouseLeaveHandler_ksdfkujsd46546_95()'onmouseenter='mouseEnterHandler_ksdfkujsd46546_95()'>
#             an extracted skill
#         </div>
#
#         <div class='absolute right-4 bottom-1 text-xs font-bold' >
#             Hard skill
#         </div>
#
#         <div class='flex flex-col w-64 left-2 -bottom-17 invisible absolute bg-white opacity-90 text-black border p-2 rounded-lg z-40' id='ksdfkujsd46546_95'>
#
#         <div class='flex grid grid-cols-2 gap-4 my-1' >
#
# ...

# %%
import en_core_web_lg
import spacy
from spacy.matcher import PhraseMatcher
from nltk.corpus import stopwords

# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor


# init params of skill extractor
nlp = en_core_web_lg.load()
stop_words = set(stopwords.words('english'))

# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher, stop_words)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
#%%timeit
# extract skills from job_description
job_description = """
You are a Python Developer with a solid experience in Web development and  esx
and have a thoughtful expatriation and manage project . You're passionate and powerful.
You are recognized for your ability to evolve within a team and around common projects
and you easily adapt in a new environment. javascript and node and french and english
"""
#job_description = 'engineering student in emines school of industrial management'
annotations = skill_extractor.annotate(job_description )
skill_extractor.display(annotations)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">you are a
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Python (Programming Language)</span>
# </mark>
#  developer with a solid experience in
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Web Development</span>
# </mark>
#  and
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     esx
# ...

# %%
annotations
# Out:
# {'text': 'you are a python developer with a solid experience in web development and esx and have a thoughtful expatriation and manage project you re passionate and powerful you are recognized for your ability to evolve within a team and around common projects and you easily adapt in a new environment javascript and node and french and english',
#  'results': {'full_matches': [{'skill_id': 'KS122Z36QK3N5097B5JH',
#     'doc_node_value': 'web development',
#     'score': 1,
#     'doc_node_id': [10, 11]}],
#   'ngram_scored': [{'skill_id': 'KS125LS6N7WP4S6SFTCK',
#     'doc_node_id': [3],
#     'doc_node_value': 'python',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS123NQ6N6KV4RM7RTXJ',
#     'doc_node_id': [13],
#     'doc_node_value': 'esx',
#     'type': 'lowSurf',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS1267F6MSPN366LX7ST',
#     'doc_node_id': [20, 21],
#     'doc_node_value': 'manage project',
#     'type': 'lowSurf',
# ...

# %%
# job_description = "We need an expert in esport management. Fluency in both english and french is mandatory!"

# annotation = skill_extractor.annotate(job_description)

# %%
# skill_extractor.display(annotation)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">we need an
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     expert
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Expert Systems</span>
# </mark>
#  in
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     esport management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">eSports Management</span>
# </mark>
#  fluency in both
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     english
# ...

# %%
# annotation
# Out:
# {'text': 'we need an expert in esport management fluency in both english and french is mandatory',
#  'results': {'full_matches': [{'skill_id': 'ES8AAD06BE8119038221',
#     'doc_node_value': 'esport management',
#     'score': 1,
#     'doc_node_id': [5, 6]}],
#   'ngram_scored': [{'skill_id': 'KS123RD5VV5WNJLMNH3J',
#     'doc_node_id': [3],
#     'doc_node_value': 'expert',
#     'type': 'lowSurf',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS123K75YYK8VGH90NCS',
#     'doc_node_id': [10],
#     'doc_node_value': 'english',
#     'type': 'lowSurf',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS1243976G466GV63ZBY',
#     'doc_node_id': [12],
#     'doc_node_value': 'french',
#     'type': 'lowSurf',
#     'score': 1,
#     'len': 1}]}}

# %%
# test of phrase
from skillNer.visualizer.phrase_class import Phrase

arr_phrases = Phrase.split_text_to_phare(annotations, SKILL_DB)

# %%
import pandas as pd

frame = { 'phrase': [] , 'is_skill': [] }
for phrase in arr_phrases:
    frame['phrase'].append(phrase.raw_text)
    frame["is_skill"].append(phrase.is_skill)

pd.DataFrame(frame)
# Out:
#               phrase  is_skill
# 0         we need an     False
# 1             expert      True
# 2                 in     False
# 3  esport management      True
# 4    fluency in both     False
# 5            english      True
# 6                and     False
# 7             french      True
# 8       is mandatory     False

# %%
id_element = "123654"
username = 'Badr MOUFAD'

print("""I know this id %s, 
yess i know it because I am %s""" % (id_element, username))
# Out:
# I know this id 123654,
# yess i know it because I am Badr MOUFAD

# %%
from skillNer.visualizer.phrase_class import Phrase

phrases = phrase.split_text_to_phare(annotations, SKILL_DB)

document(children=[
    render_phrase(phrase) for phrase in phrases
])
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="flex inline mb-48">
#
#         <div class='relative' >
#
#         <span class='flex items p-2 rounded-lg mx-2' >
#             you are a
#         </span>
#
#         </div>
#
#         <span class='relative' >
#
#         <div class='flex items border p-2 px-6 pb-6 rounded-lg mx-2 cursor-pointer' onmouseleave='mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_771()'onmouseenter='mouseEnterHandler_KS125LS6N7WP4S6SFTCK_771()'>
#             python
#         </div>
#
#         <div class='absolute right-4 bottom-1 text-xs font-bold' >
#             Hard Skill
#         </div>
#
# ...
