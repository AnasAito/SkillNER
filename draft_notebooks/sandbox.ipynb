# %%
import os
os.chdir("../")
  
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\skillNer_folder\\skillNer-repo\\SkillNER'

# %%
import en_core_web_lg
import spacy
from spacy.matcher import PhraseMatcher
from nltk.corpus import stopwords

# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
from skillNer.general_params import SKILL_DB


# init params of skill extractor
nlp = en_core_web_lg.load()

# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
#%%timeit
# extract skills from job_description
job_description = """
You are a Python developer with a solid experience in web development
and can manage projects. You quickly adapt to new environments 
and speak fluently English and French
"""


annotations = skill_extractor.annotate(job_description)

# %%
# usual display
skill_extractor.display(annotations)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">you are a
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Python (Programming Language)</span>
# </mark>
#  developer with a solid experience in
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Web Development</span>
# </mark>
#  and can
# <mark class="entity" style="background: #818CF8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manage projects
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Project Management</span>
# </mark>
#  you quickly
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adapt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Adaptability</span>
# </mark>
#  to new environments and speak fluently
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     english
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">English Language</span>
# </mark>
#  and
# <mark class="entity" style="background: #F472B6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     french
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">French Language</span>
# </mark>
# </div></span>

# %%
# details of annotations
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspyou are a&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_696()'onmouseenter='mouseEnterHandler_KS125LS6N7WP4S6SFTCK_696()'>
#             python
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS125LS6N7WP4S6SFTCK_696'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Python (Programming Language)
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS125LS6N7WP4S6SFTCK_696() {
#             document.getElementById("KS125LS6N7WP4S6SFTCK_696").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_696() {
#             document.getElementById("KS125LS6N7WP4S6SFTCK_696").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspdeveloper with a solid experience in&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS122Z36QK3N5097B5JH_419()'onmouseenter='mouseEnterHandler_KS122Z36QK3N5097B5JH_419()'>
#             web development
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS122Z36QK3N5097B5JH_419'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Web Development
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             full_matches
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS122Z36QK3N5097B5JH_419() {
#             document.getElementById("KS122Z36QK3N5097B5JH_419").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS122Z36QK3N5097B5JH_419() {
#             document.getElementById("KS122Z36QK3N5097B5JH_419").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspand can&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS1267F6MSPN366LX7ST_849()'onmouseenter='mouseEnterHandler_KS1267F6MSPN366LX7ST_849()'>
#             manage projects
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS1267F6MSPN366LX7ST_849'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Project Management
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             2
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS1267F6MSPN366LX7ST_849() {
#             document.getElementById("KS1267F6MSPN366LX7ST_849").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS1267F6MSPN366LX7ST_849() {
#             document.getElementById("KS1267F6MSPN366LX7ST_849").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspyou quickly&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_KS120626HMWCXJWJC7VK_69()'onmouseenter='mouseEnterHandler_KS120626HMWCXJWJC7VK_69()'>
#             adapt
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS120626HMWCXJWJC7VK_69'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Adaptability
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.503605
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS120626HMWCXJWJC7VK_69() {
#             document.getElementById("KS120626HMWCXJWJC7VK_69").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS120626HMWCXJWJC7VK_69() {
#             document.getElementById("KS120626HMWCXJWJC7VK_69").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspto new environments and speak fluently&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_KS123K75YYK8VGH90NCS_445()'onmouseenter='mouseEnterHandler_KS123K75YYK8VGH90NCS_445()'>
#             english
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS123K75YYK8VGH90NCS_445'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             English Language
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='fon
