# %%
# !pip install skillNer
# !python -m spacy download en_core_web_sm

# %%
# imports
import spacy
from spacy.matcher import PhraseMatcher

# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
from skillNer.general_params import SKILL_DB


# init params of skill extractor
nlp = spacy.load("en_core_web_sm")
# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
# extract skills from job_description
job_description = """
You are a Python developer with a solid experience in web development
and can manage projects. You quickly adapt to new environments 
and speak fluently English and French
"""

annotations = skill_extractor.annotate(job_description)
# Out:
# c:\Users\HP\Desktop\skillNer_folder\skillNer-repo\SkillNER\skillNer\utils.py:99: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   vec_similarity = token1.similarity(token2)

# %%
# inspect annotations
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspyou are a&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_936()'onmouseenter='mouseEnterHandler_KS125LS6N7WP4S6SFTCK_936()'>
#             python
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS125LS6N7WP4S6SFTCK_936'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Python (Programming Language)
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS125LS6N7WP4S6SFTCK_936() {
#             document.getElementById("KS125LS6N7WP4S6SFTCK_936").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_936() {
#             document.getElementById("KS125LS6N7WP4S6SFTCK_936").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspdeveloper with a solid experience in&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS122Z36QK3N5097B5JH_255()'onmouseenter='mouseEnterHandler_KS122Z36QK3N5097B5JH_255()'>
#             web development
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS122Z36QK3N5097B5JH_255'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Web Development
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             full_matches
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS122Z36QK3N5097B5JH_255() {
#             document.getElementById("KS122Z36QK3N5097B5JH_255").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS122Z36QK3N5097B5JH_255() {
#             document.getElementById("KS122Z36QK3N5097B5JH_255").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspand can&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS1267F6MSPN366LX7ST_874()'onmouseenter='mouseEnterHandler_KS1267F6MSPN366LX7ST_874()'>
#             manage projects
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS1267F6MSPN366LX7ST_874'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Project Management
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             2
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS1267F6MSPN366LX7ST_874() {
#             document.getElementById("KS1267F6MSPN366LX7ST_874").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS1267F6MSPN366LX7ST_874() {
#             document.getElementById("KS1267F6MSPN366LX7ST_874").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspyou quickly adapt to new environments and speak fluently&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_KS123K75YYK8VGH90NCS_352()'onmouseenter='mouseEnterHandler_KS123K75YYK8VGH90NCS_352()'>
#             english
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS123K75YYK8VGH90NCS_352'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             English Language
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             1
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS123K75YYK8VGH90NCS_352() {
#             document.getElementById("KS123K75YYK8VGH90NCS_352").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS123K75YYK8VGH90NCS_352() {
#             document.getElementById("KS123K75YYK8VGH90NCS_352").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspand&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_KS1243976G466GV63ZBY_949()'onmouseenter='mouseEnterHandler_KS1243976G466GV63ZBY_949()'>
#             french
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS1243976G466GV63ZBY_949'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             French Language
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <s

# %%
print(annotations)
# Out:
# {'text': 'you are a python developer with a solid experience in web development and can manage projects you quickly adapt to new environments and speak fluently english and french', 'results': {'full_matches': [{'skill_id': 'KS122Z36QK3N5097B5JH', 'doc_node_value': 'web development', 'score': 1, 'doc_node_id': [10, 11]}], 'ngram_scored': [{'skill_id': 'KS125LS6N7WP4S6SFTCK', 'doc_node_id': [3], 'doc_node_value': 'python', 'type': 'fullUni', 'score': 1, 'len': 1}, {'skill_id': 'KS1267F6MSPN366LX7ST', 'doc_node_id': [14, 15], 'doc_node_value': 'manage projects', 'type': 'lowSurf', 'score': 2, 'len': 2}, {'skill_id': 'KS123K75YYK8VGH90NCS', 'doc_node_id': [25], 'doc_node_value': 'english', 'type': 'lowSurf', 'score': 1, 'len': 1}, {'skill_id': 'KS1243976G466GV63ZBY', 'doc_node_id': [27], 'doc_node_value': 'french', 'type': 'lowSurf', 'score': 1, 'len': 1}]}}
